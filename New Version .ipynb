# %%
import requests
import pandas as pd
import numpy as np
from colorama import init, Fore, Style
import time

init(autoreset=True)

BASE_URL = "https://api.binance.com/api/v3/klines"

# Timeframes
timeframes = {
    "15m": "15m",
    "1h": "1h",
    "4h": "4h"
}

# Fetch USDT pairs
def get_usdt_pairs():
    url = "https://api.binance.com/api/v3/exchangeInfo"
    data = requests.get(url).json()
    return [s['symbol'] for s in data['symbols'] if s['quoteAsset'] == "USDT" and s['status'] == "TRADING"]

# Fetch OHLCV data
def get_klines(symbol, interval="15m", limit=100):
    try:
        url = f"{BASE_URL}?symbol={symbol}&interval={interval}&limit={limit}"
        data = requests.get(url).json()
        df = pd.DataFrame(data, columns=[
            "time","open","high","low","close","volume",
            "close_time","qav","num_trades","tbbav","tbqav","ignore"
        ])
        df["open"] = df["open"].astype(float)
        df["high"] = df["high"].astype(float)
        df["low"] = df["low"].astype(float)
        df["close"] = df["close"].astype(float)
        df["volume"] = df["volume"].astype(float)

        # Indicators
        df["ema7"] = df["close"].ewm(span=7).mean()
        df["sma21"] = df["close"].rolling(window=21).mean()
        df["rsi"] = compute_rsi(df["close"], 14)

        return df
    except Exception as e:
        print(f"⚠️ get_klines error {symbol}: {e}")
        return None

# RSI
def compute_rsi(series, period=14):
    delta = series.diff()
    up = delta.clip(lower=0)
    down = -1 * delta.clip(upper=0)
    ema_up = up.ewm(com=period-1, adjust=False).mean()
    ema_down = down.ewm(com=period-1, adjust=False).mean()
    rs = ema_up / ema_down
    return 100 - (100 / (1 + rs))

# Support & Resistance
def find_support_resistance(df):
    closes = df["close"].values
    support = np.min(closes[-20:])
    resistance = np.max(closes[-20:])
    return support, resistance

# Apply strategy (candlestick + ema/sma + rsi)
def apply_strategy(df):
    close = df["close"].iloc[-1]
    volume = df["volume"].iloc[-1]
    prev_volume = df["volume"].iloc[-2]
    ema = df["ema7"].iloc[-1]
    sma = df["sma21"].iloc[-1]
    rsi = df["rsi"].iloc[-1]
    support, resistance = find_support_resistance(df)

    patterns = []
    body = abs(df["close"].iloc[-1] - df["open"].iloc[-1])
    range_ = df["high"].iloc[-1] - df["low"].iloc[-1]
    if range_ > 0 and body / range_ < 0.1:
        patterns.append("Doji")

    return {
        "price": close,
        "volume": volume,
        "prev_volume": prev_volume,
        "ema": ema,
        "sma": sma,
        "rsi": rsi,
        "support": support,
        "resistance": resistance,
        "patterns": patterns
    }

# Run scan
def run_signal_scan():
    usdt_pairs = get_usdt_pairs()
    found = 0

    for symbol in usdt_pairs[:30]:  # Limit to 30 coins
        for tf_name, tf_interval in timeframes.items():
            try:
                df = get_klines(symbol, interval=tf_interval, limit=50)
                if df is None or len(df) < 25:
                    continue

                signal = apply_strategy(df)
                if signal:
                    arrow = "🔼" if signal['volume'] > signal['prev_volume'] else "🔽"
                    color_arrow = f"{Fore.GREEN}{arrow}" if signal['volume'] > signal['prev_volume'] else f"{Fore.RED}{arrow}"

                    print(
                        f"{symbol:<12} {tf_name:<5} {', '.join(signal['patterns']):<25} "
                        f"{signal['price']:<12.4f} {str(signal['volume']) + color_arrow:<12} "
                        f"{signal['rsi']:<10.4f} {signal['ema']:<12.4f} {signal['sma']:<12.4f} "
                        f"{signal['support']:<12.4f} {signal['resistance']:<12.4f}"
                    )
                    found += 1
            except Exception as e:
                print(f"⚠️ Error for {symbol} at {tf_name} timeframe: {e}")
                continue
            time.sleep(0.05)

    if found == 0:
        print("No signals found this round.")


if __name__ == "__main__":
    while True:
        run_signal_scan()
        time.sleep(5)   # refresh every 5 seconds

# %%
import requests
import pandas as pd
import numpy as np
from colorama import init, Fore, Style
import time

init(autoreset=True)

BASE_URL = "https://api.binance.com/api/v3/klines"

# 🔹 Apna Discord webhook yahan daalo
DISCORD_WEBHOOK_URL = "https://discord.com/api/webhooks/XXXX/XXXX"

# Timeframes
timeframes = {
    "15m": "15m",
    "1h": "1h",
    "4h": "4h"
}

# Discord par message bhejne ka function
def send_discord_message(message):
    try:
        data = {"content": message}
        response = requests.post(DISCORD_WEBHOOK_URL, json=data)
        if response.status_code == 204:
            print("✅ Discord par message bheja gaya!")
        else:
            print(f"❌ Discord Error: {response.status_code}, {response.text}")
    except Exception as e:
        print(f"⚠️ Discord error: {e}")

# Fetch USDT pairs
def get_usdt_pairs():
    url = "https://api.binance.com/api/v3/exchangeInfo"
    data = requests.get(url).json()
    return [s['symbol'] for s in data['symbols'] if s['quoteAsset'] == "USDT" and s['status'] == "TRADING"]

# Fetch OHLCV data
def get_klines(symbol, interval="15m", limit=100):
    try:
        url = f"{BASE_URL}?symbol={symbol}&interval={interval}&limit={limit}"
        data = requests.get(url).json()
        df = pd.DataFrame(data, columns=[
            "time","open","high","low","close","volume",
            "close_time","qav","num_trades","tbbav","tbqav","ignore"
        ])
        df["open"] = df["open"].astype(float)
        df["high"] = df["high"].astype(float)
        df["low"] = df["low"].astype(float)
        df["close"] = df["close"].astype(float)
        df["volume"] = df["volume"].astype(float)

        # Indicators
        df["ema7"] = df["close"].ewm(span=7).mean()
        df["sma21"] = df["close"].rolling(window=21).mean()
        df["rsi"] = compute_rsi(df["close"], 14)

        return df
    except Exception as e:
        print(f"⚠️ get_klines error {symbol}: {e}")
        return None

# RSI
def compute_rsi(series, period=14):
    delta = series.diff()
    up = delta.clip(lower=0)
    down = -1 * delta.clip(upper=0)
    ema_up = up.ewm(com=period-1, adjust=False).mean()
    ema_down = down.ewm(com=period-1, adjust=False).mean()
    rs = ema_up / ema_down
    return 100 - (100 / (1 + rs))

# Support & Resistance
def find_support_resistance(df):
    closes = df["close"].values
    support = np.min(closes[-20:])
    resistance = np.max(closes[-20:])
    return support, resistance

# Apply strategy (candlestick + ema/sma + rsi)
def apply_strategy(df):
    close = df["close"].iloc[-1]
    volume = df["volume"].iloc[-1]
    prev_volume = df["volume"].iloc[-2]
    ema = df["ema7"].iloc[-1]
    sma = df["sma21"].iloc[-1]
    rsi = df["rsi"].iloc[-1]
    support, resistance = find_support_resistance(df)

    patterns = []
    body = abs(df["close"].iloc[-1] - df["open"].iloc[-1])
    range_ = df["high"].iloc[-1] - df["low"].iloc[-1]
    if range_ > 0 and body / range_ < 0.1:
        patterns.append("Doji")

    return {
        "price": close,
        "volume": volume,
        "prev_volume": prev_volume,
        "ema": ema,
        "sma": sma,
        "rsi": rsi,
        "support": support,
        "resistance": resistance,
        "patterns": patterns
    }

# Run scan
def run_signal_scan():
    usdt_pairs = get_usdt_pairs()
    found = 0

    for symbol in usdt_pairs[:30]:  # Limit to 30 coins
        for tf_name, tf_interval in timeframes.items():
            try:
                df = get_klines(symbol, interval=tf_interval, limit=50)
                if df is None or len(df) < 25:
                    continue

                signal = apply_strategy(df)
                if signal:
                    arrow = "🔼" if signal['volume'] > signal['prev_volume'] else "🔽"

                    msg = (
                        f"**{symbol}** | {tf_name}\n"
                        f"Pattern: {', '.join(signal['patterns']) if signal['patterns'] else 'None'}\n"
                        f"Price: {signal['price']:.4f}\n"
                        f"Volume: {signal['volume']} {arrow}\n"
                        f"RSI: {signal['rsi']:.2f}\n"
                        f"EMA(7): {signal['ema']:.4f} | SMA(21): {signal['sma']:.4f}\n"
                        f"Support: {signal['support']:.4f} | Resistance: {signal['resistance']:.4f}"
                    )

                    print(msg)                # Console output
                    send_discord_message(msg) # Discord alert
                    found += 1
            except Exception as e:
                print(f"⚠️ Error for {symbol} at {tf_name} timeframe: {e}")
                continue
            time.sleep(0.05)

    if found == 0:
        print("No signals found this round.")


if __name__ == "__main__":
    while True:
        run_signal_scan()
        time.sleep(5)   # refresh every 5 seconds
# Out:
# **BTCUSDT** | 15m
# Pattern: None
# Price: 108084.0100
# Volume: 59.65866 🔽
# RSI: 56.45
# EMA(7): 107871.1972 | SMA(21): 107728.4129
# Support: 107309.9100 | Resistance: 108150.2400
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **BTCUSDT** | 1h
# Pattern: None
# Price: 108084.0000
# Volume: 291.86883 🔽
# RSI: 44.01
# EMA(7): 107968.2181 | SMA(21): 108441.3090
# Support: 107409.1000 | Resistance: 109146.6200
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **BTCUSDT** | 4h
# Pattern: None
# Price: 108084.0000
# Volume: 1485.50637 🔽
# RSI: 37.38
# EMA(7): 108340.0660 | SMA(21): 109027.6657
# Support: 107660.0100 | Resistance: 111704.2300
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ETHUSDT** | 15m
# Pattern: None
# Price: 4406.2900
# Volume: 3586.2108 🔼
# RSI: 52.25
# EMA(7): 4396.4888 | SMA(21): 4394.2957
# Support: 4374.2100 | Resistance: 4417.8200
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ETHUSDT** | 1h
# Pattern: None
# Price: 4406.2900
# Volume: 8617.0424 🔽
# RSI: 46.99
# EMA(7): 4404.9597 | SMA(21): 4442.2690
# Support: 4385.6500 | Resistance: 4489.7100
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ETHUSDT** | 4h
# Pattern: Doji
# Price: 4406.5800
# Volume: 37213.4043 🔽
# RSI: 44.05
# EMA(7): 4421.2826 | SMA(21): 4407.4719
# Support: 4316.0900 | Resistance: 4489.7500
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **BNBUSDT** | 15m
# Pattern: None
# Price: 854.4400
# Volume: 2831.675 🔼
# RSI: 46.17
# EMA(7): 853.1750 | SMA(21): 855.2219
# Support: 850.3600 | Resistance: 861.6100
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **BNBUSDT** | 1h
# Pattern: None
# Price: 854.4400
# Volume: 6805.111 🔽
# RSI: 41.60
# EMA(7): 856.1215 | SMA(21): 860.6524
# Support: 851.9900 | Resistance: 867.2000
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **BNBUSDT** | 4h
# Pattern: None
# Price: 854.4400
# Volume: 25193.804 🔽
# RSI: 39.16
# EMA(7): 858.3937 | SMA(21): 860.7543
# Support: 854.4400 | Resistance: 873.2500
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **NEOUSDT** | 15m
# Pattern: None
# Price: 6.4720
# Volume: 14303.9 🔼
# RSI: 39.81
# EMA(7): 6.4557 | SMA(21): 6.5080
# Support: 6.4100 | Resistance: 6.6730
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **NEOUSDT** | 1h
# Pattern: Doji
# Price: 6.4720
# Volume: 43163.59 🔼
# RSI: 31.43
# EMA(7): 6.5315 | SMA(21): 6.6906
# Support: 6.4320 | Resistance: 6.8110
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **NEOUSDT** | 4h
# Pattern: None
# Price: 6.4720
# Volume: 172849.38 🔽
# RSI: 29.10
# EMA(7): 6.6586 | SMA(21): 6.8031
# Support: 6.4720 | Resistance: 7.1130
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **LTCUSDT** | 15m
# Pattern: None
# Price: 108.5600
# Volume: 1486.151 🔽
# RSI: 54.40
# EMA(7): 108.1196 | SMA(21): 108.0233
# Support: 107.5100 | Resistance: 108.8000
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **LTCUSDT** | 1h
# Pattern: None
# Price: 108.5600
# Volume: 4250.223 🔽
# RSI: 39.82
# EMA(7): 108.4250 | SMA(21): 109.7381
# Support: 107.5500 | Resistance: 111.3600
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **LTCUSDT** | 4h
# Pattern: None
# Price: 108.5600
# Volume: 20599.66 🔽
# RSI: 33.47
# EMA(7): 109.4628 | SMA(21): 110.5329
# Support: 108.1000 | Resistance: 113.2300
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **QTUMUSDT** | 15m
# Pattern: None
# Price: 2.6030
# Volume: 28525.0 🔽
# RSI: 30.82
# EMA(7): 2.6201 | SMA(21): 2.7074
# Support: 2.5830 | Resistance: 2.8210
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **QTUMUSDT** | 1h
# Pattern: None
# Price: 2.6030
# Volume: 203254.4 🔽
# RSI: 31.41
# EMA(7): 2.6864 | SMA(21): 2.7498
# Support: 2.6030 | Resistance: 2.8290
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **QTUMUSDT** | 4h
# Pattern: None
# Price: 2.6030
# Volume: 681720.7 🔽
# RSI: 37.44
# EMA(7): 2.7404 | SMA(21): 2.8034
# Support: 2.6030 | Resistance: 3.0230
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ADAUSDT** | 15m
# Pattern: None
# Price: 0.8044
# Volume: 832449.2 🔽
# RSI: 47.84
# EMA(7): 0.8028 | SMA(21): 0.8046
# Support: 0.7981 | Resistance: 0.8104
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ADAUSDT** | 1h
# Pattern: Doji
# Price: 0.8044
# Volume: 3947471.5 🔽
# RSI: 39.56
# EMA(7): 0.8069 | SMA(21): 0.8170
# Support: 0.8010 | Resistance: 0.8283
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ADAUSDT** | 4h
# Pattern: None
# Price: 0.8043
# Volume: 16555644.7 🔽
# RSI: 32.51
# EMA(7): 0.8152 | SMA(21): 0.8266
# Support: 0.8043 | Resistance: 0.8526
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **XRPUSDT** | 15m
# Pattern: None
# Price: 2.7376
# Volume: 911410.9 🔽
# RSI: 46.60
# EMA(7): 2.7311 | SMA(21): 2.7372
# Support: 2.7115 | Resistance: 2.7650
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **XRPUSDT** | 1h
# Pattern: None
# Price: 2.7376
# Volume: 4319333.3 🔽
# RSI: 34.21
# EMA(7): 2.7454 | SMA(21): 2.7874
# Support: 2.7189 | Resistance: 2.8238
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **XRPUSDT** | 4h
# Pattern: Doji
# Price: 2.7377
# Volume: 22365843.8 🔽
# RSI: 26.72
# EMA(7): 2.7787 | SMA(21): 2.8282
# Support: 2.7377 | Resistance: 2.9381
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **TUSDUSDT** | 15m
# Pattern: None
# Price: 0.9966
# Volume: 6392.0 🔼
# RSI: 51.41
# EMA(7): 0.9965 | SMA(21): 0.9966
# Support: 0.9964 | Resistance: 0.9970
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **TUSDUSDT** | 1h
# Pattern: Doji
# Price: 0.9966
# Volume: 14290.0 🔼
# RSI: 49.40
# EMA(7): 0.9966 | SMA(21): 0.9965
# Support: 0.9961 | Resistance: 0.9969
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **TUSDUSDT** | 4h
# Pattern: None
# Price: 0.9966
# Volume: 18082.0 🔽
# RSI: 41.23
# EMA(7): 0.9966 | SMA(21): 0.9968
# Support: 0.9964 | Resistance: 0.9974
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **IOTAUSDT** | 15m
# Pattern: None
# Price: 0.1854
# Volume: 36651.0 🔽
# RSI: 40.61
# EMA(7): 0.1851 | SMA(21): 0.1862
# Support: 0.1841 | Resistance: 0.1888
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **IOTAUSDT** | 1h
# Pattern: None
# Price: 0.1854
# Volume: 223742.0 🔽
# RSI: 31.84
# EMA(7): 0.1867 | SMA(21): 0.1905
# Support: 0.1850 | Resistance: 0.1937
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **IOTAUSDT** | 4h
# Pattern: None
# Price: 0.1854
# Volume: 2072231.0 🔽
# RSI: 31.37
# EMA(7): 0.1894 | SMA(21): 0.1928
# Support: 0.1854 | Resistance: 0.1997
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **XLMUSDT** | 15m
# Pattern: None
# Price: 0.3488
# Volume: 881275.0 🔽
# RSI: 50.03
# EMA(7): 0.3478 | SMA(21): 0.3479
# Support: 0.3452 | Resistance: 0.3510
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **XLMUSDT** | 1h
# Pattern: None
# Price: 0.3488
# Volume: 5159520.0 🔼
# RSI: 37.72
# EMA(7): 0.3493 | SMA(21): 0.3547
# Support: 0.3464 | Resistance: 0.3599
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **XLMUSDT** | 4h
# Pattern: Doji
# Price: 0.3488
# Volume: 11491771.0 🔽
# RSI: 26.94
# EMA(7): 0.3536 | SMA(21): 0.3604
# Support: 0.3483 | Resistance: 0.3755
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ONTUSDT** | 15m
# Pattern: Doji
# Price: 0.1422
# Volume: 10836.0 🔽
# RSI: 36.83
# EMA(7): 0.1423 | SMA(21): 0.1434
# Support: 0.1415 | Resistance: 0.1464
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ONTUSDT** | 1h
# Pattern: None
# Price: 0.1422
# Volume: 300795.0 🔽
# RSI: 34.56
# EMA(7): 0.1438 | SMA(21): 0.1472
# Support: 0.1420 | Resistance: 0.1498
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ONTUSDT** | 4h
# Pattern: None
# Price: 0.1422
# Volume: 1384773.0 🔽
# RSI: 29.52
# EMA(7): 0.1466 | SMA(21): 0.1514
# Support: 0.1422 | Resistance: 0.1590
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **TRXUSDT** | 15m
# Pattern: None
# Price: 0.3379
# Volume: 2236992.7 🔽
# RSI: 41.47
# EMA(7): 0.3376 | SMA(21): 0.3381
# Support: 0.3370 | Resistance: 0.3403
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **TRXUSDT** | 1h
# Pattern: None
# Price: 0.3379
# Volume: 9319447.7 🔽
# RSI: 32.44
# EMA(7): 0.3387 | SMA(21): 0.3412
# Support: 0.3373 | Resistance: 0.3433
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **TRXUSDT** | 4h
# Pattern: None
# Price: 0.3379
# Volume: 33743760.8 🔽
# RSI: 39.47
# EMA(7): 0.3400 | SMA(21): 0.3401
# Support: 0.3342 | Resistance: 0.3441
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ETCUSDT** | 15m
# Pattern: None
# Price: 20.5100
# Volume: 2583.41 🔽
# RSI: 47.76
# EMA(7): 20.4559 | SMA(21): 20.4895
# Support: 20.3500 | Resistance: 20.7000
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ETCUSDT** | 1h
# Pattern: None
# Price: 20.5200
# Volume: 8027.88 🔽
# RSI: 38.40
# EMA(7): 20.5546 | SMA(21): 20.8381
# Support: 20.4000 | Resistance: 21.1200
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ETCUSDT** | 4h
# Pattern: Doji
# Price: 20.5200
# Volume: 70496.84 🔽
# RSI: 30.69
# EMA(7): 20.7623 | SMA(21): 20.9762
# Support: 20.5200 | Resistance: 21.5500
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ICXUSDT** | 15m
# Pattern: Doji
# Price: 0.1253
# Volume: 36536.6 🔽
# RSI: 42.86
# EMA(7): 0.1252 | SMA(21): 0.1257
# Support: 0.1247 | Resistance: 0.1276
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ICXUSDT** | 1h
# Pattern: None
# Price: 0.1253
# Volume: 187169.3 🔼
# RSI: 34.18
# EMA(7): 0.1259 | SMA(21): 0.1278
# Support: 0.1250 | Resistance: 0.1294
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ICXUSDT** | 4h
# Pattern: None
# Price: 0.1253
# Volume: 596922.9 🔽
# RSI: 35.48
# EMA(7): 0.1272 | SMA(21): 0.1282
# Support: 0.1253 | Resistance: 0.1324
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **VETUSDT** | 15m
# Pattern: None
# Price: 0.0238
# Volume: 1121713.5 🔽
# RSI: 47.92
# EMA(7): 0.0238 | SMA(21): 0.0238
# Support: 0.0236 | Resistance: 0.0241
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **VETUSDT** | 1h
# Pattern: None
# Price: 0.0238
# Volume: 4882020.5 🔽
# RSI: 37.00
# EMA(7): 0.0239 | SMA(21): 0.0243
# Support: 0.0237 | Resistance: 0.0247
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **VETUSDT** | 4h
# Pattern: None
# Price: 0.0238
# Volume: 27649286.3 🔽
# RSI: 33.64
# EMA(7): 0.0242 | SMA(21): 0.0245
# Support: 0.0238 | Resistance: 0.0253
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **USDCUSDT** | 15m
# Pattern: Doji
# Price: 0.9999
# Volume: 12644099.0 🔼
# RSI: 55.90
# EMA(7): 0.9999 | SMA(21): 0.9998
# Support: 0.9997 | Resistance: 0.9999
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **USDCUSDT** | 1h
# Pattern: None
# Price: 0.9998
# Volume: 26231250.0 🔽
# RSI: 47.10
# EMA(7): 0.9998 | SMA(21): 0.9998
# Support: 0.9997 | Resistance: 0.9999
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **USDCUSDT** | 4h
# Pattern: Doji
# Price: 0.9999
# Volume: 137999419.0 🔽
# RSI: 50.50
# EMA(7): 0.9999 | SMA(21): 0.9998
# Support: 0.9997 | Resistance: 0.9999
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **LINKUSDT** | 15m
# Pattern: None
# Price: 22.9400
# Volume: 44615.86 🔽
# RSI: 43.55
# EMA(7): 22.8942 | SMA(21): 23.0048
# Support: 22.7700 | Resistance: 23.2800
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **LINKUSDT** | 1h
# Pattern: None
# Price: 22.9400
# Volume: 509759.84 🔼
# RSI: 36.86
# EMA(7): 23.0523 | SMA(21): 23.4752
# Support: 22.8500 | Resistance: 23.9900
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **LINKUSDT** | 4h
# Pattern: None
# Price: 22.9400
# Volume: 1189574.49 🔽
# RSI: 34.18
# EMA(7): 23.3098 | SMA(21): 23.5681
# Support: 22.9400 | Resistance: 24.2300
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ONGUSDT** | 15m
# Pattern: None
# Price: 0.1649
# Volume: 54412.0 🔽
# RSI: 49.27
# EMA(7): 0.1643 | SMA(21): 0.1647
# Support: 0.1634 | Resistance: 0.1671
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ONGUSDT** | 1h
# Pattern: None
# Price: 0.1649
# Volume: 397419.0 🔽
# RSI: 41.20
# EMA(7): 0.1651 | SMA(21): 0.1671
# Support: 0.1637 | Resistance: 0.1693
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ONGUSDT** | 4h
# Pattern: None
# Price: 0.1649
# Volume: 1389905.0 🔽
# RSI: 33.56
# EMA(7): 0.1667 | SMA(21): 0.1679
# Support: 0.1642 | Resistance: 0.1704
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **HOTUSDT** | 15m
# Pattern: None
# Price: 0.0009
# Volume: 7032466.0 🔽
# RSI: 51.55
# EMA(7): 0.0009 | SMA(21): 0.0009
# Support: 0.0009 | Resistance: 0.0009
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **HOTUSDT** | 1h
# Pattern: None
# Price: 0.0009
# Volume: 46222656.0 🔼
# RSI: 40.77
# EMA(7): 0.0009 | SMA(21): 0.0009
# Support: 0.0009 | Resistance: 0.0010
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **HOTUSDT** | 4h
# Pattern: None
# Price: 0.0009
# Volume: 151872174.0 🔽
# RSI: 36.41
# EMA(7): 0.0009 | SMA(21): 0.0009
# Support: 0.0009 | Resistance: 0.0010
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ZILUSDT** | 15m
# Pattern: None
# Price: 0.0111
# Volume: 1388748.0 🔼
# RSI: 46.44
# EMA(7): 0.0111 | SMA(21): 0.0111
# Support: 0.0110 | Resistance: 0.0112
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ZILUSDT** | 1h
# Pattern: None
# Price: 0.0111
# Volume: 2389257.1 🔽
# RSI: 38.84
# EMA(7): 0.0111 | SMA(21): 0.0113
# Support: 0.0110 | Resistance: 0.0115
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ZILUSDT** | 4h
# Pattern: Doji
# Price: 0.0111
# Volume: 10587636.0 🔽
# RSI: 36.16
# EMA(7): 0.0112 | SMA(21): 0.0113
# Support: 0.0111 | Resistance: 0.0117
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ZRXUSDT** | 15m
# Pattern: None
# Price: 0.2749
# Volume: 723830.0 🔽
# RSI: 50.81
# EMA(7): 0.2784 | SMA(21): 0.2751
# Support: 0.2687 | Resistance: 0.2892
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ZRXUSDT** | 1h
# Pattern: None
# Price: 0.2750
# Volume: 3866340.0 🔽
# RSI: 58.32
# EMA(7): 0.2746 | SMA(21): 0.2661
# Support: 0.2522 | Resistance: 0.2892
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ZRXUSDT** | 4h
# Pattern: None
# Price: 0.2750
# Volume: 12448577.0 🔼
# RSI: 66.37
# EMA(7): 0.2653 | SMA(21): 0.2555
# Support: 0.2434 | Resistance: 0.2750
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **FETUSDT** | 15m
# Pattern: Doji
# Price: 0.5990
# Volume: 109258.4 🔽
# RSI: 44.45
# EMA(7): 0.5974 | SMA(21): 0.6003
# Support: 0.5940 | Resistance: 0.6110
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **FETUSDT** | 1h
# Pattern: None
# Price: 0.5990
# Volume: 503246.2 🔽
# RSI: 32.17
# EMA(7): 0.6026 | SMA(21): 0.6160
# Support: 0.5950 | Resistance: 0.6270
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **FETUSDT** | 4h
# Pattern: None
# Price: 0.5990
# Volume: 1944540.3 🔽
# RSI: 26.03
# EMA(7): 0.6126 | SMA(21): 0.6230
# Support: 0.5990 | Resistance: 0.6450
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **BATUSDT** | 15m
# Pattern: None
# Price: 0.1497
# Volume: 112082.0 🔼
# RSI: 52.89
# EMA(7): 0.1490 | SMA(21): 0.1487
# Support: 0.1475 | Resistance: 0.1499
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **BATUSDT** | 1h
# Pattern: Doji
# Price: 0.1497
# Volume: 240696.0 🔽
# RSI: 42.70
# EMA(7): 0.1497 | SMA(21): 0.1521
# Support: 0.1476 | Resistance: 0.1557
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **BATUSDT** | 4h
# Pattern: None
# Price: 0.1497
# Volume: 925409.0 🔽
# RSI: 40.88
# EMA(7): 0.1516 | SMA(21): 0.1535
# Support: 0.1490 | Resistance: 0.1593
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ZECUSDT** | 15m
# Pattern: None
# Price: 38.8700
# Volume: 393.398 🔽
# RSI: 35.03
# EMA(7): 39.0062 | SMA(21): 39.1019
# Support: 38.8300 | Resistance: 39.7500
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ZECUSDT** | 1h
# Pattern: None
# Price: 38.8700
# Volume: 3313.946 🔽
# RSI: 33.84
# EMA(7): 39.3061 | SMA(21): 40.0248
# Support: 38.8600 | Resistance: 40.9200
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ZECUSDT** | 4h
# Pattern: Doji
# Price: 38.8700
# Volume: 16355.907 🔼
# RSI: 32.96
# EMA(7): 39.7380 | SMA(21): 40.5857
# Support: 38.8700 | Resistance: 42.9900
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **IOSTUSDT** | 15m
# Pattern: None
# Price: 0.0032
# Volume: 1993154.0 🔽
# RSI: 37.54
# EMA(7): 0.0032 | SMA(21): 0.0032
# Support: 0.0032 | Resistance: 0.0033
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **IOSTUSDT** | 1h
# Pattern: None
# Price: 0.0032
# Volume: 28710860.0 🔽
# RSI: 26.27
# EMA(7): 0.0032 | SMA(21): 0.0033
# Support: 0.0032 | Resistance: 0.0033
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **IOSTUSDT** | 4h
# Pattern: None
# Price: 0.0032
# Volume: 77638178.0 🔽
# RSI: 27.43
# EMA(7): 0.0033 | SMA(21): 0.0033
# Support: 0.0032 | Resistance: 0.0034
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **CELRUSDT** | 15m
# Pattern: None
# Price: 0.0074
# Volume: 893598.7 🔽
# RSI: 46.13
# EMA(7): 0.0073 | SMA(21): 0.0074
# Support: 0.0073 | Resistance: 0.0075
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **CELRUSDT** | 1h
# Pattern: None
# Price: 0.0074
# Volume: 4133540.8 🔼
# RSI: 34.16
# EMA(7): 0.0074 | SMA(21): 0.0076
# Support: 0.0073 | Resistance: 0.0079
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **CELRUSDT** | 4h
# Pattern: Doji
# Price: 0.0074
# Volume: 16785916.5 🔽
# RSI: 33.96
# EMA(7): 0.0076 | SMA(21): 0.0078
# Support: 0.0074 | Resistance: 0.0082
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **DASHUSDT** | 15m
# Pattern: None
# Price: 23.0300
# Volume: 498.274 🔼
# RSI: 47.68
# EMA(7): 22.9421 | SMA(21): 23.0281
# Support: 22.8200 | Resistance: 23.3600
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **DASHUSDT** | 1h
# Pattern: None
# Price: 23.0300
# Volume: 829.362 🔽
# RSI: 36.25
# EMA(7): 23.1392 | SMA(21): 23.7005
# Support: 22.9000 | Resistance: 24.2700
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **DASHUSDT** | 4h
# Pattern: Doji
# Price: 23.0300
# Volume: 4013.381 🔽
# RSI: 42.45
# EMA(7): 23.4787 | SMA(21): 23.3162
# Support: 22.4900 | Resistance: 24.4000
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **THETAUSDT** | 15m
# Pattern: None
# Price: 0.7710
# Volume: 28167.5 🔽
# RSI: 49.08
# EMA(7): 0.7682 | SMA(21): 0.7690
# Support: 0.7630 | Resistance: 0.7770
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **THETAUSDT** | 1h
# Pattern: None
# Price: 0.7710
# Volume: 183239.9 🔼
# RSI: 40.64
# EMA(7): 0.7723 | SMA(21): 0.7859
# Support: 0.7630 | Resistance: 0.8020
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **THETAUSDT** | 4h
# Pattern: Doji
# Price: 0.7710
# Volume: 467133.5 🔽
# RSI: 38.40
# EMA(7): 0.7822 | SMA(21): 0.7904
# Support: 0.7710 | Resistance: 0.8240
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ENJUSDT** | 15m
# Pattern: None
# Price: 0.0662
# Volume: 369670.8 🔼
# RSI: 46.43
# EMA(7): 0.0660 | SMA(21): 0.0661
# Support: 0.0655 | Resistance: 0.0669
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ENJUSDT** | 1h
# Pattern: None
# Price: 0.0662
# Volume: 639449.3 🔽
# RSI: 38.95
# EMA(7): 0.0665 | SMA(21): 0.0679
# Support: 0.0656 | Resistance: 0.0692
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ENJUSDT** | 4h
# Pattern: Doji
# Price: 0.0662
# Volume: 2997824.4 🔽
# RSI: 37.35
# EMA(7): 0.0674 | SMA(21): 0.0678
# Support: 0.0656 | Resistance: 0.0699
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **BTCUSDT** | 15m
# Pattern: None
# Price: 108106.9100
# Volume: 80.30707 🔽
# RSI: 57.01
# EMA(7): 107876.9222 | SMA(21): 107729.5033
# Support: 107309.9100 | Resistance: 108150.2400
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **BTCUSDT** | 1h
# Pattern: None
# Price: 108106.9100
# Volume: 312.62007 🔽
# RSI: 44.45
# EMA(7): 107973.9456 | SMA(21): 108442.4000
# Support: 107409.1000 | Resistance: 109146.6200
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **BTCUSDT** | 4h
# Pattern: None
# Price: 108106.9100
# Volume: 1506.26662 🔽
# RSI: 37.61
# EMA(7): 108345.7935 | SMA(21): 109028.7567
# Support: 107660.0100 | Resistance: 111704.2300
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ETHUSDT** | 15m
# Pattern: None
# Price: 4404.2800
# Volume: 4123.9753 🔼
# RSI: 51.54
# EMA(7): 4395.9863 | SMA(21): 4394.2000
# Support: 4374.2100 | Resistance: 4417.8200
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ETHUSDT** | 1h
# Pattern: None
# Price: 4404.2800
# Volume: 9154.8069 🔽
# RSI: 46.56
# EMA(7): 4404.4572 | SMA(21): 4442.1733
# Support: 4385.6500 | Resistance: 4489.7100
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ETHUSDT** | 4h
# Pattern: Doji
# Price: 4404.2800
# Volume: 37708.9448 🔽
# RSI: 43.79
# EMA(7): 4420.7076 | SMA(21): 4407.3624
# Support: 4316.0900 | Resistance: 4489.7500
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **BNBUSDT** | 15m
# Pattern: None
# Price: 854.6000
# Volume: 2957.069 🔼
# RSI: 46.59
# EMA(7): 853.2150 | SMA(21): 855.2295
# Support: 850.3600 | Resistance: 861.6100
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **BNBUSDT** | 1h
# Pattern: None
# Price: 854.6000
# Volume: 6929.248 🔽
# RSI: 41.93
# EMA(7): 856.1615 | SMA(21): 860.6600
# Support: 851.9900 | Resistance: 867.2000
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **BNBUSDT** | 4h
# Pattern: None
# Price: 854.6000
# Volume: 25318.679 🔽
# RSI: 39.30
# EMA(7): 858.4337 | SMA(21): 860.7619
# Support: 854.6000 | Resistance: 873.2500
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **NEOUSDT** | 15m
# Pattern: None
# Price: 6.4710
# Volume: 15115.0 🔼
# RSI: 39.64
# EMA(7): 6.4554 | SMA(21): 6.5080
# Support: 6.4100 | Resistance: 6.6730
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **NEOUSDT** | 1h
# Pattern: Doji
# Price: 6.4710
# Volume: 43974.69 🔼
# RSI: 31.31
# EMA(7): 6.5313 | SMA(21): 6.6906
# Support: 6.4320 | Resistance: 6.8110
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **NEOUSDT** | 4h
# Pattern: None
# Price: 6.4710
# Volume: 173660.48 🔽
# RSI: 29.07
# EMA(7): 6.6583 | SMA(21): 6.8031
# Support: 6.4710 | Resistance: 7.1130
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **LTCUSDT** | 15m
# Pattern: None
# Price: 108.6000
# Volume: 1523.258 🔽
# RSI: 54.96
# EMA(7): 108.1296 | SMA(21): 108.0252
# Support: 107.5100 | Resistance: 108.8000
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **LTCUSDT** | 1h
# Pattern: None
# Price: 108.6000
# Volume: 4287.662 🔽
# RSI: 40.25
# EMA(7): 108.4350 | SMA(21): 109.7400
# Support: 107.5500 | Resistance: 111.3600
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **LTCUSDT** | 4h
# Pattern: None
# Price: 108.6000
# Volume: 20637.283 🔽
# RSI: 33.73
# EMA(7): 109.4728 | SMA(21): 110.5348
# Support: 108.1000 | Resistance: 113.2300
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **QTUMUSDT** | 15m
# Pattern: None
# Price: 2.5990
# Volume: 29244.6 🔽
# RSI: 29.77
# EMA(7): 2.6191 | SMA(21): 2.7072
# Support: 2.5830 | Resistance: 2.8210
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **QTUMUSDT** | 1h
# Pattern: None
# Price: 2.5990
# Volume: 203974.0 🔽
# RSI: 31.12
# EMA(7): 2.6854 | SMA(21): 2.7496
# Support: 2.5990 | Resistance: 2.8290
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **QTUMUSDT** | 4h
# Pattern: None
# Price: 2.5980
# Volume: 682461.9 🔽
# RSI: 37.23
# EMA(7): 2.7392 | SMA(21): 2.8032
# Support: 2.5980 | Resistance: 3.0230
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ADAUSDT** | 15m
# Pattern: None
# Price: 0.8041
# Volume: 881038.8 🔽
# RSI: 47.40
# EMA(7): 0.8027 | SMA(21): 0.8046
# Support: 0.7981 | Resistance: 0.8104
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ADAUSDT** | 1h
# Pattern: Doji
# Price: 0.8041
# Volume: 3996061.1 🔽
# RSI: 39.26
# EMA(7): 0.8068 | SMA(21): 0.8170
# Support: 0.8010 | Resistance: 0.8283
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ADAUSDT** | 4h
# Pattern: None
# Price: 0.8041
# Volume: 16596833.3 🔽
# RSI: 32.45
# EMA(7): 0.8152 | SMA(21): 0.8266
# Support: 0.8041 | Resistance: 0.8526
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **XRPUSDT** | 15m
# Pattern: None
# Price: 2.7393
# Volume: 988132.1 🔽
# RSI: 47.55
# EMA(7): 2.7315 | SMA(21): 2.7372
# Support: 2.7115 | Resistance: 2.7650
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **XRPUSDT** | 1h
# Pattern: None
# Price: 2.7393
# Volume: 4396054.5 🔽
# RSI: 34.90
# EMA(7): 2.7459 | SMA(21): 2.7875
# Support: 2.7189 | Resistance: 2.8238
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **XRPUSDT** | 4h
# Pattern: Doji
# Price: 2.7393
# Volume: 22443007.2 🔽
# RSI: 26.88
# EMA(7): 2.7791 | SMA(21): 2.8282
# Support: 2.7393 | Resistance: 2.9381
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **TUSDUSDT** | 15m
# Pattern: None
# Price: 0.9967
# Volume: 6423.0 🔼
# RSI: 55.46
# EMA(7): 0.9966 | SMA(21): 0.9966
# Support: 0.9964 | Resistance: 0.9970
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **TUSDUSDT** | 1h
# Pattern: None
# Price: 0.9967
# Volume: 14321.0 🔼
# RSI: 52.96
# EMA(7): 0.9966 | SMA(21): 0.9965
# Support: 0.9961 | Resistance: 0.9969
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **TUSDUSDT** | 4h
# Pattern: None
# Price: 0.9967
# Volume: 18113.0 🔽
# RSI: 43.10
# EMA(7): 0.9966 | SMA(21): 0.9968
# Support: 0.9964 | Resistance: 0.9974
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **IOTAUSDT** | 15m
# Pattern: None
# Price: 0.1854
# Volume: 36651.0 🔽
# RSI: 40.61
# EMA(7): 0.1851 | SMA(21): 0.1862
# Support: 0.1841 | Resistance: 0.1888
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **IOTAUSDT** | 1h
# Pattern: None
# Price: 0.1854
# Volume: 223742.0 🔽
# RSI: 31.84
# EMA(7): 0.1867 | SMA(21): 0.1905
# Support: 0.1850 | Resistance: 0.1937
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **IOTAUSDT** | 4h
# Pattern: None
# Price: 0.1854
# Volume: 2072231.0 🔽
# RSI: 31.37
# EMA(7): 0.1894 | SMA(21): 0.1928
# Support: 0.1854 | Resistance: 0.1997
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **XLMUSDT** | 15m
# Pattern: None
# Price: 0.3486
# Volume: 887915.0 🔽
# RSI: 49.38
# EMA(7): 0.3478 | SMA(21): 0.3479
# Support: 0.3452 | Resistance: 0.3510
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **XLMUSDT** | 1h
# Pattern: None
# Price: 0.3486
# Volume: 5166160.0 🔼
# RSI: 37.18
# EMA(7): 0.3492 | SMA(21): 0.3547
# Support: 0.3464 | Resistance: 0.3599
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **XLMUSDT** | 4h
# Pattern: Doji
# Price: 0.3486
# Volume: 11498411.0 🔽
# RSI: 26.59
# EMA(7): 0.3535 | SMA(21): 0.3604
# Support: 0.3483 | Resistance: 0.3755
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ONTUSDT** | 15m
# Pattern: Doji
# Price: 0.1422
# Volume: 10906.0 🔽
# RSI: 36.83
# EMA(7): 0.1423 | SMA(21): 0.1434
# Support: 0.1415 | Resistance: 0.1464
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ONTUSDT** | 1h
# Pattern: None
# Price: 0.1422
# Volume: 300865.0 🔽
# RSI: 34.56
# EMA(7): 0.1438 | SMA(21): 0.1472
# Support: 0.1420 | Resistance: 0.1498
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ONTUSDT** | 4h
# Pattern: None
# Price: 0.1422
# Volume: 1384843.0 🔽
# RSI: 29.52
# EMA(7): 0.1466 | SMA(21): 0.1514
# Support: 0.1422 | Resistance: 0.1590
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **TRXUSDT** | 15m
# Pattern: None
# Price: 0.3379
# Volume: 2247262.7 🔽
# RSI: 41.47
# EMA(7): 0.3376 | SMA(21): 0.3381
# Support: 0.3370 | Resistance: 0.3403
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **TRXUSDT** | 1h
# Pattern: None
# Price: 0.3379
# Volume: 9329717.7 🔽
# RSI: 32.44
# EMA(7): 0.3387 | SMA(21): 0.3412
# Support: 0.3373 | Resistance: 0.3433
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **TRXUSDT** | 4h
# Pattern: None
# Price: 0.3379
# Volume: 33754030.8 🔽
# RSI: 39.47
# EMA(7): 0.3400 | SMA(21): 0.3401
# Support: 0.3342 | Resistance: 0.3441
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ETCUSDT** | 15m
# Pattern: None
# Price: 20.5100
# Volume: 2653.52 🔽
# RSI: 47.76
# EMA(7): 20.4559 | SMA(21): 20.4895
# Support: 20.3500 | Resistance: 20.7000
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ETCUSDT** | 1h
# Pattern: None
# Price: 20.5100
# Volume: 8095.05 🔽
# RSI: 37.89
# EMA(7): 20.5521 | SMA(21): 20.8376
# Support: 20.4000 | Resistance: 21.1200
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ETCUSDT** | 4h
# Pattern: Doji
# Price: 20.5100
# Volume: 70564.01 🔽
# RSI: 30.54
# EMA(7): 20.7598 | SMA(21): 20.9757
# Support: 20.5100 | Resistance: 21.5500
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ICXUSDT** | 15m
# Pattern: Doji
# Price: 0.1253
# Volume: 39416.6 🔽
# RSI: 42.86
# EMA(7): 0.1252 | SMA(21): 0.1257
# Support: 0.1247 | Resistance: 0.1276
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ICXUSDT** | 1h
# Pattern: None
# Price: 0.1253
# Volume: 190049.3 🔼
# RSI: 34.18
# EMA(7): 0.1259 | SMA(21): 0.1278
# Support: 0.1250 | Resistance: 0.1294
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ICXUSDT** | 4h
# Pattern: None
# Price: 0.1253
# Volume: 599802.9 🔽
# RSI: 35.48
# EMA(7): 0.1272 | SMA(21): 0.1282
# Support: 0.1253 | Resistance: 0.1324
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **VETUSDT** | 15m
# Pattern: None
# Price: 0.0238
# Volume: 1278036.3 🔽
# RSI: 47.92
# EMA(7): 0.0238 | SMA(21): 0.0238
# Support: 0.0236 | Resistance: 0.0241
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **VETUSDT** | 1h
# Pattern: None
# Price: 0.0238
# Volume: 5038343.3 🔽
# RSI: 37.00
# EMA(7): 0.0239 | SMA(21): 0.0243
# Support: 0.0237 | Resistance: 0.0247
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **VETUSDT** | 4h
# Pattern: None
# Price: 0.0238
# Volume: 27805609.1 🔽
# RSI: 33.64
# EMA(7): 0.0242 | SMA(21): 0.0245
# Support: 0.0238 | Resistance: 0.0253
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **USDCUSDT** | 15m
# Pattern: None
# Price: 0.9998
# Volume: 15567975.0 🔼
# RSI: 50.17
# EMA(7): 0.9998 | SMA(21): 0.9998
# Support: 0.9997 | Resistance: 0.9999
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **USDCUSDT** | 1h
# Pattern: Doji
# Price: 0.9999
# Volume: 29154666.0 🔽
# RSI: 54.36
# EMA(7): 0.9999 | SMA(21): 0.9998
# Support: 0.9997 | Resistance: 0.9999
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **USDCUSDT** | 4h
# Pattern: Doji
# Price: 0.9999
# Volume: 140923127.0 🔽
# RSI: 50.50
# EMA(7): 0.9999 | SMA(21): 0.9998
# Support: 0.9997 | Resistance: 0.9999
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **LINKUSDT** | 15m
# Pattern: None
# Price: 22.9400
# Volume: 46295.92 🔽
# RSI: 43.55
# EMA(7): 22.8942 | SMA(21): 23.0048
# Support: 22.7700 | Resistance: 23.2800
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **LINKUSDT** | 1h
# Pattern: None
# Price: 22.9400
# Volume: 511439.9 🔼
# RSI: 36.86
# EMA(7): 23.0523 | SMA(21): 23.4752
# Support: 22.8500 | Resistance: 23.9900
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **LINKUSDT** | 4h
# Pattern: None
# Price: 22.9400
# Volume: 1191254.55 🔽
# RSI: 34.18
# EMA(7): 23.3098 | SMA(21): 23.5681
# Support: 22.9400 | Resistance: 24.2300
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ONGUSDT** | 15m
# Pattern: None
# Price: 0.1647
# Volume: 66164.0 🔽
# RSI: 47.31
# EMA(7): 0.1643 | SMA(21): 0.1647
# Support: 0.1634 | Resistance: 0.1671
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ONGUSDT** | 1h
# Pattern: None
# Price: 0.1647
# Volume: 409171.0 🔼
# RSI: 40.14
# EMA(7): 0.1651 | SMA(21): 0.1671
# Support: 0.1637 | Resistance: 0.1693
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ONGUSDT** | 4h
# Pattern: Doji
# Price: 0.1647
# Volume: 1401657.0 🔽
# RSI: 32.87
# EMA(7): 0.1666 | SMA(21): 0.1679
# Support: 0.1642 | Resistance: 0.1704
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **HOTUSDT** | 15m
# Pattern: None
# Price: 0.0009
# Volume: 11199147.0 🔽
# RSI: 51.55
# EMA(7): 0.0009 | SMA(21): 0.0009
# Support: 0.0009 | Resistance: 0.0009
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **HOTUSDT** | 1h
# Pattern: None
# Price: 0.0009
# Volume: 50389337.0 🔼
# RSI: 40.77
# EMA(7): 0.0009 | SMA(21): 0.0009
# Support: 0.0009 | Resistance: 0.0010
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **HOTUSDT** | 4h
# Pattern: None
# Price: 0.0009
# Volume: 156038855.0 🔽
# RSI: 36.41
# EMA(7): 0.0009 | SMA(21): 0.0009
# Support: 0.0009 | Resistance: 0.0010
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ZILUSDT** | 15m
# Pattern: None
# Price: 0.0111
# Volume: 0.0 🔽
# RSI: 46.44
# EMA(7): 0.0111 | SMA(21): 0.0111
# Support: 0.0110 | Resistance: 0.0111
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ZILUSDT** | 1h
# Pattern: None
# Price: 0.0111
# Volume: 2424807.1 🔽
# RSI: 38.84
# EMA(7): 0.0111 | SMA(21): 0.0113
# Support: 0.0110 | Resistance: 0.0115
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ZILUSDT** | 4h
# Pattern: Doji
# Price: 0.0111
# Volume: 10623186.0 🔽
# RSI: 36.16
# EMA(7): 0.0112 | SMA(21): 0.0113
# Support: 0.0111 | Resistance: 0.0117
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ZRXUSDT** | 15m
# Pattern: None
# Price: 0.2746
# Volume: 6578.0 🔽
# RSI: 51.69
# EMA(7): 0.2775 | SMA(21): 0.2754
# Support: 0.2691 | Resistance: 0.2892
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ZRXUSDT** | 1h
# Pattern: None
# Price: 0.2748
# Volume: 3943177.0 🔽
# RSI: 58.14
# EMA(7): 0.2745 | SMA(21): 0.2661
# Support: 0.2522 | Resistance: 0.2892
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ZRXUSDT** | 4h
# Pattern: None
# Price: 0.2748
# Volume: 12526235.0 🔼
# RSI: 66.24
# EMA(7): 0.2653 | SMA(21): 0.2555
# Support: 0.2434 | Resistance: 0.2748
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **FETUSDT** | 15m
# Pattern: None
# Price: 0.6000
# Volume: 0.0 🔽
# RSI: 45.58
# EMA(7): 0.5982 | SMA(21): 0.5997
# Support: 0.5940 | Resistance: 0.6070
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **FETUSDT** | 1h
# Pattern: None
# Price: 0.6000
# Volume: 503561.3 🔽
# RSI: 33.66
# EMA(7): 0.6029 | SMA(21): 0.6161
# Support: 0.5950 | Resistance: 0.6270
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **FETUSDT** | 4h
# Pattern: Doji
# Price: 0.6000
# Volume: 1944855.4 🔽
# RSI: 26.41
# EMA(7): 0.6128 | SMA(21): 0.6230
# Support: 0.6000 | Resistance: 0.6450
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **BATUSDT** | 15m
# Pattern: None
# Price: 0.1497
# Volume: 0.0 🔽
# RSI: 53.46
# EMA(7): 0.1492 | SMA(21): 0.1487
# Support: 0.1475 | Resistance: 0.1498
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **BATUSDT** | 1h
# Pattern: Doji
# Price: 0.1497
# Volume: 246128.0 🔽
# RSI: 42.70
# EMA(7): 0.1497 | SMA(21): 0.1521
# Support: 0.1476 | Resistance: 0.1557
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **BATUSDT** | 4h
# Pattern: None
# Price: 0.1497
# Volume: 930841.0 🔽
# RSI: 40.88
# EMA(7): 0.1516 | SMA(21): 0.1535
# Support: 0.1490 | Resistance: 0.1593
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ZECUSDT** | 15m
# Pattern: None
# Price: 38.9100
# Volume: 77.569 🔽
# RSI: 42.08
# EMA(7): 38.9822 | SMA(21): 39.0486
# Support: 38.8300 | Resistance: 39.5500
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ZECUSDT** | 1h
# Pattern: None
# Price: 38.9100
# Volume: 3391.515 🔽
# RSI: 34.24
# EMA(7): 39.3161 | SMA(21): 40.0267
# Support: 38.8600 | Resistance: 40.9200
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ZECUSDT** | 4h
# Pattern: Doji
# Price: 38.9100
# Volume: 16433.476 🔼
# RSI: 33.17
# EMA(7): 39.7480 | SMA(21): 40.5876
# Support: 38.9100 | Resistance: 42.9900
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **IOSTUSDT** | 15m
# Pattern: None
# Price: 0.0032
# Volume: 0.0 🔽
# RSI: 38.80
# EMA(7): 0.0032 | SMA(21): 0.0032
# Support: 0.0032 | Resistance: 0.0032
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **IOSTUSDT** | 1h
# Pattern: None
# Price: 0.0032
# Volume: 28710860.0 🔽
# RSI: 26.27
# EMA(7): 0.0032 | SMA(21): 0.0033
# Support: 0.0032 | Resistance: 0.0033
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **IOSTUSDT** | 4h
# Pattern: None
# Price: 0.0032
# Volume: 77638178.0 🔽
# RSI: 27.43
# EMA(7): 0.0033 | SMA(21): 0.0033
# Support: 0.0032 | Resistance: 0.0034
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **CELRUSDT** | 15m
# Pattern: None
# Price: 0.0074
# Volume: 2842.0 🔽
# RSI: 46.64
# EMA(7): 0.0073 | SMA(21): 0.0074
# Support: 0.0073 | Resistance: 0.0074
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **CELRUSDT** | 1h
# Pattern: None
# Price: 0.0074
# Volume: 4141491.5 🔼
# RSI: 34.16
# EMA(7): 0.0074 | SMA(21): 0.0076
# Support: 0.0073 | Resistance: 0.0079
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **CELRUSDT** | 4h
# Pattern: Doji
# Price: 0.0074
# Volume: 16793867.2 🔽
# RSI: 33.96
# EMA(7): 0.0076 | SMA(21): 0.0078
# Support: 0.0074 | Resistance: 0.0082
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **DASHUSDT** | 15m
# Pattern: None
# Price: 23.0500
# Volume: 0.0 🔽
# RSI: 43.83
# EMA(7): 22.9728 | SMA(21): 23.0110
# Support: 22.8200 | Resistance: 23.2400
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **DASHUSDT** | 1h
# Pattern: None
# Price: 23.0500
# Volume: 857.515 🔽
# RSI: 36.88
# EMA(7): 23.1442 | SMA(21): 23.7014
# Support: 22.9000 | Resistance: 24.2700
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **DASHUSDT** | 4h
# Pattern: Doji
# Price: 23.0500
# Volume: 4041.534 🔽
# RSI: 42.71
# EMA(7): 23.4837 | SMA(21): 23.3171
# Support: 22.4900 | Resistance: 24.4000
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **THETAUSDT** | 15m
# Pattern: None
# Price: 0.7710
# Volume: 0.0 🔽
# RSI: 49.08
# EMA(7): 0.7689 | SMA(21): 0.7685
# Support: 0.7630 | Resistance: 0.7720
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **THETAUSDT** | 1h
# Pattern: None
# Price: 0.7710
# Volume: 183239.9 🔼
# RSI: 40.64
# EMA(7): 0.7723 | SMA(21): 0.7859
# Support: 0.7630 | Resistance: 0.8020
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **THETAUSDT** | 4h
# Pattern: Doji
# Price: 0.7710
# Volume: 467133.5 🔽
# RSI: 38.40
# EMA(7): 0.7822 | SMA(21): 0.7904
# Support: 0.7710 | Resistance: 0.8240
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ENJUSDT** | 15m
# Pattern: None
# Price: 0.0661
# Volume: 5615.5 🔽
# RSI: 44.83
# EMA(7): 0.0660 | SMA(21): 0.0661
# Support: 0.0655 | Resistance: 0.0664
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ENJUSDT** | 1h
# Pattern: None
# Price: 0.0661
# Volume: 645064.8 🔽
# RSI: 37.97
# EMA(7): 0.0664 | SMA(21): 0.0679
# Support: 0.0656 | Resistance: 0.0692
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ENJUSDT** | 4h
# Pattern: None
# Price: 0.0661
# Volume: 3003439.9 🔽
# RSI: 37.01
# EMA(7): 0.0674 | SMA(21): 0.0678
# Support: 0.0656 | Resistance: 0.0699
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **BTCUSDT** | 15m
# Pattern: None
# Price: 108082.0000
# Volume: 2.53514 🔽
# RSI: 54.75
# EMA(7): 107927.1678 | SMA(21): 107718.8962
# Support: 107309.9100 | Resistance: 108101.4500
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **BTCUSDT** | 1h
# Pattern: None
# Price: 108081.9900
# Volume: 320.00667 🔽
# RSI: 43.97
# EMA(7): 107967.7156 | SMA(21): 108441.2133
# Support: 107409.1000 | Resistance: 109146.6200
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **BTCUSDT** | 4h
# Pattern: None
# Price: 108075.5800
# Volume: 1513.83442 🔽
# RSI: 37.29
# EMA(7): 108337.9610 | SMA(21): 109027.2648
# Support: 107660.0100 | Resistance: 111704.2300
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ETHUSDT** | 15m
# Pattern: None
# Price: 4405.1600
# Volume: 91.0878 🔽
# RSI: 52.51
# EMA(7): 4398.5310 | SMA(21): 4393.2848
# Support: 4374.2100 | Resistance: 4405.9900
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ETHUSDT** | 1h
# Pattern: None
# Price: 4405.1600
# Volume: 9305.2107 🔽
# RSI: 46.75
# EMA(7): 4404.6772 | SMA(21): 4442.2152
# Support: 4385.6500 | Resistance: 4489.7100
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ETHUSDT** | 4h
# Pattern: Doji
# Price: 4405.1600
# Volume: 37858.4165 🔽
# RSI: 43.89
# EMA(7): 4420.9276 | SMA(21): 4407.4043
# Support: 4316.0900 | Resistance: 4489.7500
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **BNBUSDT** | 15m
# Pattern: None
# Price: 855.0200
# Volume: 190.607 🔽
# RSI: 48.51
# EMA(7): 853.6756 | SMA(21): 854.7810
# Support: 850.3600 | Resistance: 861.3600
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **BNBUSDT** | 1h
# Pattern: None
# Price: 855.0200
# Volume: 7183.715 🔽
# RSI: 42.79
# EMA(7): 856.2665 | SMA(21): 860.6800
# Support: 851.9900 | Resistance: 867.2000
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **BNBUSDT** | 4h
# Pattern: None
# Price: 855.0100
# Volume: 25574.425 🔽
# RSI: 39.65
# EMA(7): 858.5362 | SMA(21): 860.7814
# Support: 854.6100 | Resistance: 873.2500
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **NEOUSDT** | 15m
# Pattern: None
# Price: 6.4720
# Volume: 406.68 🔽
# RSI: 40.82
# EMA(7): 6.4596 | SMA(21): 6.4978
# Support: 6.4100 | Resistance: 6.6080
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **NEOUSDT** | 1h
# Pattern: Doji
# Price: 6.4720
# Volume: 44384.37 🔼
# RSI: 31.43
# EMA(7): 6.5315 | SMA(21): 6.6906
# Support: 6.4320 | Resistance: 6.8110
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **NEOUSDT** | 4h
# Pattern: None
# Price: 6.4710
# Volume: 174073.16 🔽
# RSI: 29.07
# EMA(7): 6.6583 | SMA(21): 6.8031
# Support: 6.4710 | Resistance: 7.1130
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **LTCUSDT** | 15m
# Pattern: Doji
# Price: 108.5900
# Volume: 70.324 🔽
# RSI: 54.54
# EMA(7): 108.2428 | SMA(21): 107.9976
# Support: 107.5100 | Resistance: 108.5900
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **LTCUSDT** | 1h
# Pattern: None
# Price: 108.5900
# Volume: 4373.71 🔽
# RSI: 40.14
# EMA(7): 108.4325 | SMA(21): 109.7395
# Support: 107.5500 | Resistance: 111.3600
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **LTCUSDT** | 4h
# Pattern: None
# Price: 108.5900
# Volume: 20723.147 🔽
# RSI: 33.67
# EMA(7): 109.4703 | SMA(21): 110.5343
# Support: 108.1000 | Resistance: 113.2300
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **QTUMUSDT** | 15m
# Pattern: None
# Price: 2.6000
# Volume: 84.9 🔽
# RSI: 30.62
# EMA(7): 2.6149 | SMA(21): 2.6964
# Support: 2.5830 | Resistance: 2.8080
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **QTUMUSDT** | 1h
# Pattern: None
# Price: 2.6000
# Volume: 204099.3 🔽
# RSI: 31.19
# EMA(7): 2.6856 | SMA(21): 2.7497
# Support: 2.6000 | Resistance: 2.8290
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **QTUMUSDT** | 4h
# Pattern: None
# Price: 2.6000
# Volume: 682565.6 🔽
# RSI: 37.31
# EMA(7): 2.7397 | SMA(21): 2.8033
# Support: 2.6000 | Resistance: 3.0230
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ADAUSDT** | 15m
# Pattern: None
# Price: 0.8040
# Volume: 23358.6 🔽
# RSI: 47.01
# EMA(7): 0.8030 | SMA(21): 0.8042
# Support: 0.7981 | Resistance: 0.8091
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ADAUSDT** | 1h
# Pattern: Doji
# Price: 0.8040
# Volume: 4028317.7 🔽
# RSI: 39.16
# EMA(7): 0.8068 | SMA(21): 0.8170
# Support: 0.8010 | Resistance: 0.8283
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ADAUSDT** | 4h
# Pattern: None
# Price: 0.8040
# Volume: 16629089.9 🔽
# RSI: 32.42
# EMA(7): 0.8152 | SMA(21): 0.8266
# Support: 0.8040 | Resistance: 0.8526
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **XRPUSDT** | 15m
# Pattern: None
# Price: 2.7395
# Volume: 99445.0 🔽
# RSI: 47.19
# EMA(7): 2.7335 | SMA(21): 2.7356
# Support: 2.7115 | Resistance: 2.7522
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **XRPUSDT** | 1h
# Pattern: None
# Price: 2.7395
# Volume: 4498611.1 🔽
# RSI: 34.98
# EMA(7): 2.7459 | SMA(21): 2.7875
# Support: 2.7189 | Resistance: 2.8238
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **XRPUSDT** | 4h
# Pattern: Doji
# Price: 2.7396
# Volume: 22545224.5 🔽
# RSI: 26.91
# EMA(7): 2.7792 | SMA(21): 2.8282
# Support: 2.7396 | Resistance: 2.9381
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **TUSDUSDT** | 15m
# Pattern: None
# Price: 0.9966
# Volume: 114.0 🔽
# RSI: 50.90
# EMA(7): 0.9966 | SMA(21): 0.9966
# Support: 0.9964 | Resistance: 0.9970
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **TUSDUSDT** | 1h
# Pattern: Doji
# Price: 0.9966
# Volume: 14525.0 🔼
# RSI: 49.40
# EMA(7): 0.9966 | SMA(21): 0.9965
# Support: 0.9961 | Resistance: 0.9969
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **TUSDUSDT** | 4h
# Pattern: None
# Price: 0.9966
# Volume: 18317.0 🔽
# RSI: 41.23
# EMA(7): 0.9966 | SMA(21): 0.9968
# Support: 0.9964 | Resistance: 0.9974
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **IOTAUSDT** | 15m
# Pattern: None
# Price: 0.1854
# Volume: 1411.0 🔽
# RSI: 41.25
# EMA(7): 0.1851 | SMA(21): 0.1860
# Support: 0.1841 | Resistance: 0.1882
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **IOTAUSDT** | 1h
# Pattern: None
# Price: 0.1854
# Volume: 225153.0 🔽
# RSI: 31.84
# EMA(7): 0.1867 | SMA(21): 0.1905
# Support: 0.1850 | Resistance: 0.1937
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **IOTAUSDT** | 4h
# Pattern: None
# Price: 0.1854
# Volume: 2073642.0 🔽
# RSI: 31.37
# EMA(7): 0.1894 | SMA(21): 0.1928
# Support: 0.1854 | Resistance: 0.1997
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **XLMUSDT** | 15m
# Pattern: None
# Price: 0.3489
# Volume: 12941.0 🔽
# RSI: 50.12
# EMA(7): 0.3481 | SMA(21): 0.3477
# Support: 0.3452 | Resistance: 0.3492
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **XLMUSDT** | 1h
# Pattern: None
# Price: 0.3489
# Volume: 5202158.0 🔼
# RSI: 37.99
# EMA(7): 0.3493 | SMA(21): 0.3547
# Support: 0.3464 | Resistance: 0.3599
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **XLMUSDT** | 4h
# Pattern: None
# Price: 0.3489
# Volume: 11534409.0 🔽
# RSI: 27.11
# EMA(7): 0.3536 | SMA(21): 0.3604
# Support: 0.3483 | Resistance: 0.3755
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ONTUSDT** | 15m
# Pattern: None
# Price: 0.1420
# Volume: 1556.0 🔽
# RSI: 35.32
# EMA(7): 0.1423 | SMA(21): 0.1432
# Support: 0.1415 | Resistance: 0.1448
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ONTUSDT** | 1h
# Pattern: None
# Price: 0.1420
# Volume: 302421.0 🔽
# ...
# EMA(7): 39.7530 | SMA(21): 40.5886
# Support: 38.9300 | Resistance: 42.9900
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **IOSTUSDT** | 15m
# Pattern: None
# Price: 0.0032
# Volume: 180209.0 🔽
# RSI: 37.92
# EMA(7): 0.0032 | SMA(21): 0.0032
# Support: 0.0032 | Resistance: 0.0032
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **IOSTUSDT** | 1h
# Pattern: None
# Price: 0.0032
# Volume: 28891069.0 🔽
# RSI: 25.88
# EMA(7): 0.0032 | SMA(21): 0.0033
# Support: 0.0032 | Resistance: 0.0033
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **IOSTUSDT** | 4h
# Pattern: None
# Price: 0.0032
# Volume: 77818387.0 🔽
# RSI: 27.25
# EMA(7): 0.0033 | SMA(21): 0.0033
# Support: 0.0032 | Resistance: 0.0034
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **CELRUSDT** | 15m
# Pattern: None
# Price: 0.0074
# Volume: 344622.4 🔽
# RSI: 47.96
# EMA(7): 0.0073 | SMA(21): 0.0074
# Support: 0.0073 | Resistance: 0.0074
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **CELRUSDT** | 1h
# Pattern: None
# Price: 0.0074
# Volume: 4483271.9 🔼
# RSI: 34.93
# EMA(7): 0.0074 | SMA(21): 0.0076
# Support: 0.0073 | Resistance: 0.0079
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **CELRUSDT** | 4h
# Pattern: Doji
# Price: 0.0074
# Volume: 17135647.6 🔽
# RSI: 34.14
# EMA(7): 0.0076 | SMA(21): 0.0078
# Support: 0.0074 | Resistance: 0.0082
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **DASHUSDT** | 15m
# Pattern: None
# Price: 23.0500
# Volume: 0.0 🔽
# RSI: 43.83
# EMA(7): 22.9728 | SMA(21): 23.0110
# Support: 22.8200 | Resistance: 23.2400
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **DASHUSDT** | 1h
# Pattern: None
# Price: 23.0500
# Volume: 857.515 🔽
# RSI: 36.88
# EMA(7): 23.1442 | SMA(21): 23.7014
# Support: 22.9000 | Resistance: 24.2700
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **DASHUSDT** | 4h
# Pattern: Doji
# Price: 23.0500
# Volume: 4041.534 🔽
# RSI: 42.71
# EMA(7): 23.4837 | SMA(21): 23.3171
# Support: 22.4900 | Resistance: 24.4000
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **THETAUSDT** | 15m
# Pattern: None
# Price: 0.7700
# Volume: 15.7 🔽
# RSI: 47.41
# EMA(7): 0.7686 | SMA(21): 0.7685
# Support: 0.7630 | Resistance: 0.7720
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **THETAUSDT** | 1h
# Pattern: None
# Price: 0.7700
# Volume: 183255.6 🔼
# RSI: 39.74
# EMA(7): 0.7720 | SMA(21): 0.7858
# Support: 0.7630 | Resistance: 0.8020
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **THETAUSDT** | 4h
# Pattern: Doji
# Price: 0.7700
# Volume: 467149.2 🔽
# RSI: 38.07
# EMA(7): 0.7819 | SMA(21): 0.7904
# Support: 0.7700 | Resistance: 0.8240
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ENJUSDT** | 15m
# Pattern: None
# Price: 0.0661
# Volume: 5615.5 🔽
# RSI: 44.83
# EMA(7): 0.0660 | SMA(21): 0.0661
# Support: 0.0655 | Resistance: 0.0664
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ENJUSDT** | 1h
# Pattern: None
# Price: 0.0661
# Volume: 645064.8 🔽
# RSI: 37.97
# EMA(7): 0.0664 | SMA(21): 0.0679
# Support: 0.0656 | Resistance: 0.0692
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ENJUSDT** | 4h
# Pattern: None
# Price: 0.0661
# Volume: 3003439.9 🔽
# RSI: 37.01
# EMA(7): 0.0674 | SMA(21): 0.0678
# Support: 0.0656 | Resistance: 0.0699
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **BTCUSDT** | 15m
# Pattern: None
# Price: 108052.2800
# Volume: 5.41024 🔽
# RSI: 53.77
# EMA(7): 107919.7378 | SMA(21): 107717.4810
# Support: 107309.9100 | Resistance: 108101.4500
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **BTCUSDT** | 1h
# Pattern: None
# Price: 108052.2800
# Volume: 322.90423 🔽
# RSI: 43.38
# EMA(7): 107960.2881 | SMA(21): 108439.7986
# Support: 107409.1000 | Resistance: 109146.6200
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **BTCUSDT** | 4h
# Pattern: None
# Price: 108052.2800
# Volume: 1516.52769 🔽
# RSI: 37.05
# EMA(7): 108332.1360 | SMA(21): 109026.1552
# Support: 107660.0100 | Resistance: 111704.2300
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ETHUSDT** | 15m
# Pattern: None
# Price: 4404.0800
# Volume: 273.151 🔽
# RSI: 52.08
# EMA(7): 4398.2610 | SMA(21): 4393.2333
# Support: 4374.2100 | Resistance: 4405.9900
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ETHUSDT** | 1h
# Pattern: None
# Price: 4404.0800
# Volume: 9487.2739 🔽
# RSI: 46.51
# EMA(7): 4404.4072 | SMA(21): 4442.1638
# Support: 4385.6500 | Resistance: 4489.7100
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ETHUSDT** | 4h
# Pattern: Doji
# Price: 4404.0800
# Volume: 38040.4797 🔽
# RSI: 43.77
# EMA(7): 4420.6576 | SMA(21): 4407.3529
# Support: 4316.0900 | Resistance: 4489.7500
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **BNBUSDT** | 15m
# Pattern: None
# Price: 854.9700
# Volume: 378.658 🔽
# RSI: 48.38
# EMA(7): 853.6631 | SMA(21): 854.7786
# Support: 850.3600 | Resistance: 861.3600
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **BNBUSDT** | 1h
# Pattern: None
# Price: 854.9700
# Volume: 7373.766 🔽
# RSI: 42.69
# EMA(7): 856.2540 | SMA(21): 860.6776
# Support: 851.9900 | Resistance: 867.2000
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **BNBUSDT** | 4h
# Pattern: None
# Price: 854.9700
# Volume: 25762.444 🔽
# RSI: 39.62
# EMA(7): 858.5262 | SMA(21): 860.7795
# Support: 854.6100 | Resistance: 873.2500
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **NEOUSDT** | 15m
# Pattern: None
# Price: 6.4720
# Volume: 1068.49 🔽
# RSI: 40.82
# EMA(7): 6.4596 | SMA(21): 6.4978
# Support: 6.4100 | Resistance: 6.6080
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **NEOUSDT** | 1h
# Pattern: Doji
# Price: 6.4720
# Volume: 45047.27 🔼
# RSI: 31.43
# EMA(7): 6.5315 | SMA(21): 6.6906
# Support: 6.4320 | Resistance: 6.8110
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **NEOUSDT** | 4h
# Pattern: None
# Price: 6.4720
# Volume: 174735.08 🔽
# RSI: 29.10
# EMA(7): 6.6586 | SMA(21): 6.8031
# Support: 6.4720 | Resistance: 7.1130
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **LTCUSDT** | 15m
# Pattern: None
# Price: 108.6000
# Volume: 121.599 🔽
# RSI: 54.69
# EMA(7): 108.2453 | SMA(21): 107.9981
# Support: 107.5100 | Resistance: 108.6000
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **LTCUSDT** | 1h
# Pattern: None
# Price: 108.6000
# Volume: 4420.381 🔽
# RSI: 40.25
# EMA(7): 108.4350 | SMA(21): 109.7400
# Support: 107.5500 | Resistance: 111.3600
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **LTCUSDT** | 4h
# Pattern: None
# Price: 108.5800
# Volume: 20774.422 🔽
# RSI: 33.60
# EMA(7): 109.4678 | SMA(21): 110.5338
# Support: 108.1000 | Resistance: 113.2300
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **QTUMUSDT** | 15m
# Pattern: None
# Price: 2.6020
# Volume: 387.8 🔽
# RSI: 30.86
# EMA(7): 2.6154 | SMA(21): 2.6965
# Support: 2.5830 | Resistance: 2.8080
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **QTUMUSDT** | 1h
# Pattern: None
# Price: 2.6020
# Volume: 204402.2 🔽
# RSI: 31.33
# EMA(7): 2.6861 | SMA(21): 2.7498
# Support: 2.6020 | Resistance: 2.8290
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **QTUMUSDT** | 4h
# Pattern: None
# Price: 2.6020
# Volume: 682868.5 🔽
# RSI: 37.40
# EMA(7): 2.7402 | SMA(21): 2.8034
# Support: 2.6020 | Resistance: 3.0230
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ADAUSDT** | 15m
# Pattern: None
# Price: 0.8038
# Volume: 28840.0 🔽
# RSI: 46.73
# EMA(7): 0.8030 | SMA(21): 0.8042
# Support: 0.7981 | Resistance: 0.8091
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ADAUSDT** | 1h
# Pattern: Doji
# Price: 0.8038
# Volume: 4033799.1 🔽
# RSI: 38.95
# EMA(7): 0.8067 | SMA(21): 0.8170
# Support: 0.8010 | Resistance: 0.8283
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **ADAUSDT** | 4h
# Pattern: None
# Price: 0.8037
# Volume: 16639324.3 🔽
# RSI: 32.32
# EMA(7): 0.8151 | SMA(21): 0.8266
# Support: 0.8037 | Resistance: 0.8526
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **XRPUSDT** | 15m
# Pattern: None
# Price: 2.7388
# Volume: 141894.8 🔽
# RSI: 46.80
# EMA(7): 2.7333 | SMA(21): 2.7355
# Support: 2.7115 | Resistance: 2.7522
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **XRPUSDT** | 1h
# Pattern: None
# Price: 2.7386
# Volume: 4541116.0 🔽
# RSI: 34.62
# EMA(7): 2.7457 | SMA(21): 2.7875
# Support: 2.7189 | Resistance: 2.8238
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **XRPUSDT** | 4h
# Pattern: Doji
# Price: 2.7386
# Volume: 22587620.0 🔽
# RSI: 26.81
# EMA(7): 2.7789 | SMA(21): 2.8282
# Support: 2.7386 | Resistance: 2.9381
# ❌ Discord Error: 400, {"webhook_id": ["Value \"XXXX\" is not snowflake."]}
# **TUSDUSDT** | 15m
# Pattern: None
# Price: 0.9965
# Volume: 765.0 🔽
# RSI: 47.03
# EMA(7): 0.9965 | SMA(21): 0.9966
# Support: 0.9964 | Resistance: 0.9970
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 149
#     147 if __name__ == "__main__":
#     148     while True:
# --> 149         run_signal_scan()
#     150         time.sleep(5)
#
# Cell In[1], line 136, in run_signal_scan()
#     125         msg = (
#     126             f"**{symbol}** | {tf_name}\n"
#     127             f"Pattern: {', '.join(signal['patterns']) if signal['patterns'] else 'None'}\n"
#    (...)
#     132             f"Support: {signal['support']:.4f} | Resistance: {signal['resistance']:.4f}"
#     133         )
#     135         print(msg)                # Console output
# --> 136         send_discord_message(msg) # Discord alert
#     137         found += 1
#     138 except Exception as e:
#
# Cell In[1], line 25, in send_discord_message(message)
#      23 try:
#      24     data = {"content": message}
# ---> 25     response = requests.post(DISCORD_WEBHOOK_URL, json=data)
#      26     if response.status_code == 204:
#      27         print("✅ Discord par message bheja gaya!")
#
# File ~\anaconda3\envs\binance_env\Lib\site-packages\requests\api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File ~\anaconda3\envs\binance_env\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\anaconda3\envs\binance_env\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\anaconda3\envs\binance_env\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~\anaconda3\envs\binance_env\Lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~\anaconda3\envs\binance_env\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~\anaconda3\envs\binance_env\Lib\site-packages\urllib3\connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~\anaconda3\envs\binance_env\Lib\site-packages\urllib3\connection.py:516, in HTTPConnection.getresponse(self)
#     513 _shutdown = getattr(self.sock, "shutdown", None)
#     515 # Get the response from http.client.HTTPConnection
# --> 516 httplib_response = super().getresponse()
#     518 try:
#     519     assert_header_parsing(httplib_response.msg)
#
# File ~\anaconda3\envs\binance_env\Lib\http\client.py:1430, in HTTPConnection.getresponse(self)
#    1428 try:
#    1429     try:
# -> 1430         response.begin()
#    1431     except ConnectionError:
#    1432         self.close()
#
# File ~\anaconda3\envs\binance_env\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File ~\anaconda3\envs\binance_env\Lib\http\client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File ~\anaconda3\envs\binance_env\Lib\socket.py:720, in SocketIO.readinto(self, b)
#     718 while True:
#     719     try:
# --> 720         return self._sock.recv_into(b)
#     721     except timeout:
#     722         self._timeout_occurred = True
#
# File ~\anaconda3\envs\binance_env\Lib\ssl.py:1251, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1247     if flags != 0:
#    1248         raise ValueError(
#    1249           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1250           self.__class__)
# -> 1251     return self.read(nbytes, buffer)
#    1252 else:
#    1253     return super().recv_into(buffer, nbytes, flags)
#
# File ~\anaconda3\envs\binance_env\Lib\ssl.py:1103, in SSLSocket.read(self, len, buffer)
#    1101 try:
#    1102     if buffer is not None:
# -> 1103         return self._sslobj.read(len, buffer)
#    1104     else:
#    1105         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import requests
import pandas as pd
import numpy as np
from colorama import init, Fore
import time

init(autoreset=True)

BASE_URL = "https://api.binance.com/api/v3/klines"
PRICE_URL = "https://api.binance.com/api/v3/ticker/24hr"

# 🔹 Apna Discord webhook URL yahan paste karo
DISCORD_WEBHOOK_URL = "https://discord.com/api/webhooks/1411968945476337786/kMj3PfIomoBv9xWPg72LXKldILJpgEptlP0wT7m85yxJ9z1UsDDF-ePTq7Log9nNhF2M"

# Timeframes
timeframes = {
    "15m": "15m",
    "1h": "1h",
    "4h": "4h"
}

# Discord par message bhejne ka function
def send_discord_message(message):
    try:
        data = {"content": message}
        response = requests.post(DISCORD_WEBHOOK_URL, json=data)
        if response.status_code == 204:
            print("✅ Discord par message bheja gaya!")
        else:
            print(f"❌ Discord Error: {response.status_code}, {response.text}")
    except Exception as e:
        print(f"⚠️ Discord error: {e}")

# Fetch USDT pairs
def get_usdt_pairs():
    url = "https://api.binance.com/api/v3/exchangeInfo"
    data = requests.get(url).json()
    return [s['symbol'] for s in data['symbols'] if s['quoteAsset'] == "USDT" and s['status'] == "TRADING"]

# Fetch OHLCV data
def get_klines(symbol, interval="15m", limit=100):
    try:
        url = f"{BASE_URL}?symbol={symbol}&interval={interval}&limit={limit}"
        data = requests.get(url).json()
        df = pd.DataFrame(data, columns=[
            "time","open","high","low","close","volume",
            "close_time","qav","num_trades","tbbav","tbqav","ignore"
        ])
        df["open"] = df["open"].astype(float)
        df["high"] = df["high"].astype(float)
        df["low"] = df["low"].astype(float)
        df["close"] = df["close"].astype(float)
        df["volume"] = df["volume"].astype(float)

        # Indicators
        df["ema7"] = df["close"].ewm(span=7).mean()
        df["sma21"] = df["close"].rolling(window=21).mean()
        df["rsi"] = compute_rsi(df["close"], 14)

        return df
    except Exception as e:
        print(f"⚠️ get_klines error {symbol}: {e}")
        return None

# RSI
def compute_rsi(series, period=14):
    delta = series.diff()
    up = delta.clip(lower=0)
    down = -1 * delta.clip(upper=0)
    ema_up = up.ewm(com=period-1, adjust=False).mean()
    ema_down = down.ewm(com=period-1, adjust=False).mean()
    rs = ema_up / ema_down
    return 100 - (100 / (1 + rs))

# Support & Resistance
def find_support_resistance(df):
    closes = df["close"].values
    support = np.min(closes[-20:])
    resistance = np.max(closes[-20:])
    return support, resistance

# Candlestick Pattern Detector
def detect_patterns(df):
    patterns = []
    o, h, l, c = df["open"].iloc[-1], df["high"].iloc[-1], df["low"].iloc[-1], df["close"].iloc[-1]
    prev_o, prev_c = df["open"].iloc[-2], df["close"].iloc[-2]

    body = abs(c - o)
    range_ = h - l

    # Doji
    if range_ > 0 and body / range_ < 0.1:
        patterns.append("Doji")

    # Hammer
    if body < (h - l) * 0.3 and (o - l) > body * 2 and (c - l) > body * 2:
        patterns.append("Hammer")

    # Shooting Star
    if body < (h - l) * 0.3 and (h - o) > body * 2 and (h - c) > body * 2:
        patterns.append("Shooting Star")

    # Bullish Engulfing
    if prev_c < prev_o and c > o and c > prev_o and o < prev_c:
        patterns.append("Bullish Engulfing")

    # Bearish Engulfing
    if prev_c > prev_o and c < o and c < prev_o and o > prev_c:
        patterns.append("Bearish Engulfing")

    # Morning Star
    if prev_c < prev_o and abs(o - c) < body * 0.3 and c > prev_o:
        patterns.append("Morning Star")

    # Evening Star
    if prev_c > prev_o and abs(o - c) < body * 0.3 and c < prev_o:
        patterns.append("Evening Star")

    return patterns

# Apply strategy
def apply_strategy(df):
    close = df["close"].iloc[-1]
    volume = df["volume"].iloc[-1]
    prev_volume = df["volume"].iloc[-2]
    ema = df["ema7"].iloc[-1]
    sma = df["sma21"].iloc[-1]
    rsi = df["rsi"].iloc[-1]
    support, resistance = find_support_resistance(df)
    patterns = detect_patterns(df)

    # Filtering logic
    strong_signal = False
    reasons = []

    if rsi < 30:
        strong_signal = True
        reasons.append("RSI Oversold (<30)")
    if rsi > 70:
        strong_signal = True
        reasons.append("RSI Overbought (>70)")
    if ema > sma:
        reasons.append("Bullish Crossover (EMA > SMA)")
    if ema < sma:
        reasons.append("Bearish Crossover (EMA < SMA)")
    if patterns:
        strong_signal = True
        reasons.extend(patterns)

    return {
        "price": close,
        "volume": volume,
        "prev_volume": prev_volume,
        "ema": ema,
        "sma": sma,
        "rsi": rsi,
        "support": support,
        "resistance": resistance,
        "patterns": patterns,
        "strong": strong_signal,
        "reasons": reasons
    }

# 🔹 Top Movers (24h change %)
def get_top_movers(limit=10):
    try:
        data = requests.get(PRICE_URL).json()
        df = pd.DataFrame(data)
        df = df[df["symbol"].str.endswith("USDT")]
        df["priceChangePercent"] = df["priceChangePercent"].astype(float)
        df = df.sort_values("priceChangePercent", ascending=False)
        top_gainers = df.head(limit)[["symbol","lastPrice","priceChangePercent"]]
        top_losers = df.tail(limit)[["symbol","lastPrice","priceChangePercent"]]
        return top_gainers, top_losers
    except Exception as e:
        print(f"⚠️ Top movers error: {e}")
        return None, None

# Run scan
def run_signal_scan():
    usdt_pairs = get_usdt_pairs()
    found = 0

    # Top 150 coins only
    top_pairs = usdt_pairs[:150]

    for symbol in top_pairs:
        confirmations = {}

        for tf_name, tf_interval in timeframes.items():
            try:
                df = get_klines(symbol, interval=tf_interval, limit=50)
                if df is None or len(df) < 25:
                    continue

                signal = apply_strategy(df)
                confirmations[tf_name] = signal

            except Exception as e:
                print(f"⚠️ Error for {symbol} at {tf_name} timeframe: {e}")
                continue
            time.sleep(0.05)

        # Multi-timeframe confirmation
        if all(confirmations.values()):
            strong_tfs = [tf for tf, sig in confirmations.items() if sig["strong"]]
            if len(strong_tfs) >= 2:  # At least 2 TF agree
                last_signal = confirmations["15m"]  # base on 15m
                arrow = "🔼" if last_signal['volume'] > last_signal['prev_volume'] else "🔽"

                msg = (
                    f"🚨 **{symbol} Signal**\n"
                    f"Confirmed on: {', '.join(strong_tfs)}\n"
                    f"Reasons: {', '.join(last_signal['reasons'])}\n"
                    f"Price: {last_signal['price']:.4f}\n"
                    f"Volume: {last_signal['volume']} {arrow}\n"
                    f"RSI: {last_signal['rsi']:.2f}\n"
                    f"EMA(7): {last_signal['ema']:.4f} | SMA(21): {last_signal['sma']:.4f}\n"
                    f"Support: {last_signal['support']:.4f} | Resistance: {last_signal['resistance']:.4f}"
                )

                print(msg)
                send_discord_message(msg)
                found += 1

    if found == 0:
        print("No strong signals found this round.")

    # 🔹 Send Top Movers once every scan
    gainers, losers = get_top_movers(limit=5)
    if gainers is not None:
        gm = "**📈 Top Gainers (24h)**\n" + "\n".join(
            [f"{row['symbol']}: {row['lastPrice']} ({row['priceChangePercent']}%)" for _, row in gainers.iterrows()]
        )
        lm = "**📉 Top Losers (24h)**\n" + "\n".join(
            [f"{row['symbol']}: {row['lastPrice']} ({row['priceChangePercent']}%)" for _, row in losers.iterrows()]
        )
        send_discord_message(gm + "\n\n" + lm)


if __name__ == "__main__":
    while True:
        run_signal_scan()
        time.sleep(15)   # refresh every 15 seconds
# Out:
# 🚨 **ONTUSDT Signal**
# Confirmed on: 15m, 1h, 4h
# Reasons: Bearish Crossover (EMA < SMA), Shooting Star
# Price: 0.1422
# Volume: 36689.0 🔽
# RSI: 34.07
# EMA(7): 0.1423 | SMA(21): 0.1430
# Support: 0.1415 | Resistance: 0.1444
# ✅ Discord par message bheja gaya!
# 🚨 **TRXUSDT Signal**
# Confirmed on: 15m, 1h, 4h
# Reasons: Bearish Crossover (EMA < SMA), Doji, Hammer, Shooting Star
# Price: 0.3381
# Volume: 1938902.9 🔼
# RSI: 43.31
# EMA(7): 0.3378 | SMA(21): 0.3379
# Support: 0.3370 | Resistance: 0.3384
# ✅ Discord par message bheja gaya!
# 🚨 **USDCUSDT Signal**
# Confirmed on: 15m, 1h, 4h
# Reasons: Bullish Crossover (EMA > SMA), Doji, Hammer
# Price: 0.9999
# Volume: 1493040.0 🔽
# RSI: 53.98
# EMA(7): 0.9999 | SMA(21): 0.9998
# Support: 0.9997 | Resistance: 0.9999
# ✅ Discord par message bheja gaya!
# 🚨 **LINKUSDT Signal**
# Confirmed on: 15m, 1h, 4h
# Reasons: Bearish Crossover (EMA < SMA), Shooting Star
# Price: 22.9900
# Volume: 13822.03 🔽
# RSI: 43.93
# EMA(7): 22.9305 | SMA(21): 22.9729
# Support: 22.7700 | Resistance: 23.1300
# ✅ Discord par message bheja gaya!
# 🚨 **ZRXUSDT Signal**
# Confirmed on: 15m, 1h, 4h
# Reasons: Bullish Crossover (EMA > SMA), Doji, Hammer, Shooting Star
# Price: 0.2739
# Volume: 220668.0 🔽
# RSI: 49.03
# EMA(7): 0.2764 | SMA(21): 0.2756
# Support: 0.2691 | Resistance: 0.2892
# ✅ Discord par message bheja gaya!
# 🚨 **IOSTUSDT Signal**
# Confirmed on: 1h, 4h
# Reasons: Bearish Crossover (EMA < SMA)
# Price: 0.0032
# Volume: 621274.0 🔽
# RSI: 38.27
# EMA(7): 0.0032 | SMA(21): 0.0032
# Support: 0.0032 | Resistance: 0.0032
# ✅ Discord par message bheja gaya!
# 🚨 **ONEUSDT Signal**
# Confirmed on: 15m, 4h
# Reasons: Bearish Crossover (EMA < SMA), Bullish Engulfing
# Price: 0.0101
# Volume: 816898.9 🔽
# RSI: 41.44
# EMA(7): 0.0101 | SMA(21): 0.0101
# Support: 0.0100 | Resistance: 0.0102
# ✅ Discord par message bheja gaya!
# 🚨 **FUNUSDT Signal**
# Confirmed on: 15m, 1h, 4h
# Reasons: Bearish Crossover (EMA < SMA), Shooting Star
# Price: 0.0095
# Volume: 325524.0 🔽
# RSI: 52.94
# EMA(7): 0.0095 | SMA(21): 0.0095
# Support: 0.0094 | Resistance: 0.0095
# ✅ Discord par message bheja gaya!
# 🚨 **HBARUSDT Signal**
# Confirmed on: 1h, 4h
# Reasons: Bearish Crossover (EMA < SMA)
# Price: 0.2137
# Volume: 336715.0 🔽
# RSI: 39.50
# EMA(7): 0.2136 | SMA(21): 0.2140
# Support: 0.2125 | Resistance: 0.2151
# ✅ Discord par message bheja gaya!
# 🚨 **BCHUSDT Signal**
# Confirmed on: 15m, 1h, 4h
# Reasons: Bullish Crossover (EMA > SMA), Bullish Engulfing
# Price: 535.1000
# Volume: 58.881 🔽
# RSI: 44.16
# EMA(7): 534.2619 | SMA(21): 534.1667
# Support: 530.8000 | Resistance: 535.9000
# ✅ Discord par message bheja gaya!
# 🚨 **FTTUSDT Signal**
# Confirmed on: 1h, 4h
# Reasons: Bearish Crossover (EMA < SMA)
# Price: 0.7973
# Volume: 872.3 🔽
# RSI: 38.73
# EMA(7): 0.7970 | SMA(21): 0.8014
# Support: 0.7930 | Resistance: 0.8086
# ✅ Discord par message bheja gaya!
# 🚨 **EURUSDT Signal**
# Confirmed on: 15m, 1h
# Reasons: RSI Overbought (>70), Bullish Crossover (EMA > SMA), Shooting Star
# Price: 1.1721
# Volume: 37792.7 🔽
# RSI: 71.83
# EMA(7): 1.1718 | SMA(21): 1.1708
# Support: 1.1698 | Resistance: 1.1727
# ✅ Discord par message bheja gaya!
# 🚨 **DATAUSDT Signal**
# Confirmed on: 1h, 4h
# Reasons: Bearish Crossover (EMA < SMA)
# Price: 0.0160
# Volume: 28315.9 🔽
# RSI: 46.70
# EMA(7): 0.0159 | SMA(21): 0.0160
# Support: 0.0158 | Resistance: 0.0163
# ✅ Discord par message bheja gaya!
# 🚨 **CTSIUSDT Signal**
# Confirmed on: 15m, 1h
# Reasons: Bearish Crossover (EMA < SMA), Doji, Shooting Star
# Price: 0.0747
# Volume: 32794.0 🔽
# RSI: 45.41
# EMA(7): 0.0747 | SMA(21): 0.0749
# Support: 0.0742 | Resistance: 0.0756
# ✅ Discord par message bheja gaya!
# 🚨 **MDTUSDT Signal**
# Confirmed on: 15m, 1h, 4h
# Reasons: Bearish Crossover (EMA < SMA), Shooting Star
# Price: 0.0268
# Volume: 299749.8 🔽
# RSI: 44.03
# EMA(7): 0.0272 | SMA(21): 0.0276
# Support: 0.0266 | Resistance: 0.0291
# ✅ Discord par message bheja gaya!
# 🚨 **DOTUSDT Signal**
# Confirmed on: 15m, 1h
# Reasons: Bullish Crossover (EMA > SMA), Doji, Hammer, Shooting Star
# Price: 3.7020
# Volume: 16674.63 🔽
# RSI: 46.33
# EMA(7): 3.6961 | SMA(21): 3.6881
# Support: 3.6640 | Resistance: 3.7100
# ✅ Discord par message bheja gaya!
# 🚨 **RSRUSDT Signal**
# Confirmed on: 15m, 1h, 4h
# Reasons: Bearish Crossover (EMA < SMA), Doji, Shooting Star
# Price: 0.0072
# Volume: 4510479.4 🔼
# RSI: 41.56
# EMA(7): 0.0072 | SMA(21): 0.0072
# Support: 0.0071 | Resistance: 0.0072
# ✅ Discord par message bheja gaya!
# 🚨 **PAXGUSDT Signal**
# Confirmed on: 1h, 4h
# Reasons: Bullish Crossover (EMA > SMA)
# Price: 3496.2300
# Volume: 23.2449 🔽
# RSI: 64.34
# EMA(7): 3497.3875 | SMA(21): 3491.7262
# Support: 3477.3100 | Resistance: 3501.0400
# ✅ Discord par message bheja gaya!
# 🚨 **TRBUSDT Signal**
# Confirmed on: 15m, 1h
# Reasons: Bullish Crossover (EMA > SMA), Doji, Hammer, Shooting Star
# Price: 32.8200
# Volume: 283.409 🔽
# RSI: 50.57
# EMA(7): 32.7309 | SMA(21): 32.5852
# Support: 32.3400 | Resistance: 32.8400
# ✅ Discord par message bheja gaya!
# 🚨 **SUSHIUSDT Signal**
# Confirmed on: 15m, 1h, 4h
# Reasons: Bullish Crossover (EMA > SMA), Shooting Star
# Price: 0.7425
# Volume: 34627.3 🔽
# RSI: 43.99
# EMA(7): 0.7410 | SMA(21): 0.7395
# Support: 0.7311 | Resistance: 0.7451
# ✅ Discord par message bheja gaya!
# 🚨 **KSMUSDT Signal**
# Confirmed on: 15m, 1h
# Reasons: Bearish Crossover (EMA < SMA), Hammer, Shooting Star
# Price: 15.0600
# Volume: 843.917 🔼
# RSI: 40.34
# EMA(7): 15.0580 | SMA(21): 15.0967
# Support: 14.9800 | Resistance: 15.2500
# ✅ Discord par message bheja gaya!
# 🚨 **EGLDUSDT Signal**
# Confirmed on: 15m, 1h, 4h
# Reasons: Bullish Crossover (EMA > SMA), Doji, Hammer, Shooting Star
# Price: 13.9400
# Volume: 1047.6 🔽
# RSI: 42.63
# EMA(7): 13.9248 | SMA(21): 13.9229
# Support: 13.8300 | Resistance: 14.0000
# ✅ Discord par message bheja gaya!
# 🚨 **DIAUSDT Signal**
# Confirmed on: 15m, 1h, 4h
# Reasons: Bullish Crossover (EMA > SMA), Shooting Star
# Price: 0.6856
# Volume: 3113.1 🔼
# RSI: 42.76
# EMA(7): 0.6852 | SMA(21): 0.6852
# Support: 0.6818 | Resistance: 0.6877
# ✅ Discord par message bheja gaya!
# 🚨 **RUNEUSDT Signal**
# Confirmed on: 1h, 4h
# Reasons: Bearish Crossover (EMA < SMA)
# Price: 1.1690
# Volume: 53773.9 🔼
# RSI: 41.48
# EMA(7): 1.1673 | SMA(21): 1.1682
# Support: 1.1580 | Resistance: 1.1790
# ✅ Discord par message bheja gaya!
# 🚨 **FIOUSDT Signal**
# Confirmed on: 15m, 1h, 4h
# Reasons: Bullish Crossover (EMA > SMA), Doji, Shooting Star
# Price: 0.0192
# Volume: 275220.0 🔼
# RSI: 42.62
# EMA(7): 0.0191 | SMA(21): 0.0191
# Support: 0.0190 | Resistance: 0.0194
# ✅ Discord par message bheja gaya!
# 🚨 **UNIUSDT Signal**
# Confirmed on: 15m, 1h
# Reasons: Bullish Crossover (EMA > SMA), Doji, Hammer, Shooting Star
# Price: 9.4510
# Volume: 9003.96 🔽
# RSI: 44.32
# EMA(7): 9.4399 | SMA(21): 9.4190
# Support: 9.3580 | Resistance: 9.4760
# ✅ Discord par message bheja gaya!
# 🚨 **OXTUSDT Signal**
# Confirmed on: 15m, 1h, 4h
# Reasons: Bullish Crossover (EMA > SMA), Doji, Hammer, Shooting Star
# Price: 0.0526
# Volume: 87317.0 🔽
# RSI: 40.70
# EMA(7): 0.0526 | SMA(21): 0.0526
# Support: 0.0523 | Resistance: 0.0529
# ✅ Discord par message bheja gaya!
# 🚨 **AVAXUSDT Signal**
# Confirmed on: 15m, 1h, 4h
# Reasons: Bearish Crossover (EMA < SMA), Shooting Star
# Price: 23.1000
# Volume: 6178.95 🔽
# RSI: 41.51
# EMA(7): 23.0704 | SMA(21): 23.0890
# Support: 22.9200 | Resistance: 23.2200
# ✅ Discord par message bheja gaya!
# 🚨 **UTKUSDT Signal**
# Confirmed on: 15m, 1h, 4h
# Reasons: Bearish Crossover (EMA < SMA), Doji, Hammer, Shooting Star
# Price: 0.0307
# Volume: 34376.0 🔽
# RSI: 44.81
# EMA(7): 0.0307 | SMA(21): 0.0307
# Support: 0.0305 | Resistance: 0.0309
# ✅ Discord par message bheja gaya!
# 🚨 **AAVEUSDT Signal**
# Confirmed on: 15m, 1h
# Reasons: Bearish Crossover (EMA < SMA), Doji, Hammer, Shooting Star
# Price: 310.1900
# Volume: 195.771 🔽
# RSI: 38.97
# EMA(7): 310.3274 | SMA(21): 310.8648
# Support: 309.0400 | Resistance: 312.4300
# ✅ Discord par message bheja gaya!
# 🚨 **AUDIOUSDT Signal**
# Confirmed on: 15m, 1h
# Reasons: Bearish Crossover (EMA < SMA), Doji, Hammer, Shooting Star
# Price: 0.0615
# Volume: 61805.3 🔽
# RSI: 41.40
# EMA(7): 0.0616 | SMA(21): 0.0617
# Support: 0.0613 | Resistance: 0.0619
# ✅ Discord par message bheja gaya!
# 🚨 **ROSEUSDT Signal**
# Confirmed on: 15m, 1h, 4h
# Reasons: Bullish Crossover (EMA > SMA), Shooting Star
# Price: 0.0239
# Volume: 309951.3 🔽
# RSI: 42.06
# EMA(7): 0.0239 | SMA(21): 0.0238
# Support: 0.0236 | Resistance: 0.0240
# ✅ Discord par message bheja gaya!
# 🚨 **AVAUSDT Signal**
# Confirmed on: 15m, 1h, 4h
# Reasons: Bullish Crossover (EMA > SMA), Doji, Shooting Star
# Price: 0.5292
# Volume: 3649.4 🔼
# RSI: 47.23
# EMA(7): 0.5286 | SMA(21): 0.5282
# Support: 0.5249 | Resistance: 0.5306
# ✅ Discord par message bheja gaya!
# 🚨 **JUVUSDT Signal**
# Confirmed on: 15m, 1h
# Reasons: Bullish Crossover (EMA > SMA), Bearish Engulfing
# Price: 1.1770
# Volume: 23297.19 🔽
# RSI: 55.51
# EMA(7): 1.1771 | SMA(21): 1.1610
# Support: 1.1400 | Resistance: 1.1990
# ✅ Discord par message bheja gaya!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 243
#     241 if __name__ == "__main__":
#     242     while True:
# --> 243         run_signal_scan()
#     244         time.sleep(15)
#
# Cell In[3], line 192, in run_signal_scan()
#     190 for tf_name, tf_interval in timeframes.items():
#     191     try:
# --> 192         df = get_klines(symbol, interval=tf_interval, limit=50)
#     193         if df is None or len(df) < 25:
#     194             continue
#
# Cell In[3], line 44, in get_klines(symbol, interval, limit)
#      42 try:
#      43     url = f"{BASE_URL}?symbol={symbol}&interval={interval}&limit={limit}"
# ---> 44     data = requests.get(url).json()
#      45     df = pd.DataFrame(data, columns=[
#      46         "time","open","high","low","close","volume",
#      47         "close_time","qav","num_trades","tbbav","tbqav","ignore"
#      48     ])
#      49     df["open"] = df["open"].astype(float)
#
# File ~\anaconda3\envs\binance_env\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~\anaconda3\envs\binance_env\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\anaconda3\envs\binance_env\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\anaconda3\envs\binance_env\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~\anaconda3\envs\binance_env\Lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~\anaconda3\envs\binance_env\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~\anaconda3\envs\binance_env\Lib\site-packages\urllib3\connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~\anaconda3\envs\binance_env\Lib\site-packages\urllib3\connection.py:516, in HTTPConnection.getresponse(self)
#     513 _shutdown = getattr(self.sock, "shutdown", None)
#     515 # Get the response from http.client.HTTPConnection
# --> 516 httplib_response = super().getresponse()
#     518 try:
#     519     assert_header_parsing(httplib_response.msg)
#
# File ~\anaconda3\envs\binance_env\Lib\http\client.py:1430, in HTTPConnection.getresponse(self)
#    1428 try:
#    1429     try:
# -> 1430         response.begin()
#    1431     except ConnectionError:
#    1432         self.close()
#
# File ~\anaconda3\envs\binance_env\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File ~\anaconda3\envs\binance_env\Lib\http\client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File ~\anaconda3\envs\binance_env\Lib\socket.py:720, in SocketIO.readinto(self, b)
#     718 while True:
#     719     try:
# --> 720         return self._sock.recv_into(b)
#     721     except timeout:
#     722         self._timeout_occurred = True
#
# File ~\anaconda3\envs\binance_env\Lib\ssl.py:1251, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1247     if flags != 0:
#    1248         raise ValueError(
#    1249           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1250           self.__class__)
# -> 1251     return self.read(nbytes, buffer)
#    1252 else:
#    1253     return super().recv_into(buffer, nbytes, flags)
#
# File ~\anaconda3\envs\binance_env\Lib\ssl.py:1103, in SSLSocket.read(self, len, buffer)
#    1101 try:
#    1102     if buffer is not None:
# -> 1103         return self._sslobj.read(len, buffer)
#    1104     else:
#    1105         return self._sslobj.read(len)
#
# KeyboardInterrupt:
